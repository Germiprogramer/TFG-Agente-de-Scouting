# %%
# !pip install statsbombpy
# !pip install mplsoccer
# !pip install highlight_text
# !pip install fuzzywuzzy[speedup]
# !pip install rapidfuzz pandas
# Out:
# Requirement already satisfied: statsbombpy in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (1.14.0)
# Requirement already satisfied: pandas in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from statsbombpy) (2.2.0)
# Requirement already satisfied: requests in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from statsbombpy) (2.31.0)
# Requirement already satisfied: requests-cache in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from statsbombpy) (1.2.1)
# Requirement already satisfied: inflect in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from statsbombpy) (7.4.0)
# Requirement already satisfied: joblib in c:\users\germán llorente\appdata\roaming\python\python39\site-packages (from statsbombpy) (1.2.0)
# Requirement already satisfied: more-itertools>=8.5.0 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from inflect->statsbombpy) (10.5.0)
# Requirement already satisfied: typeguard>=4.0.1 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from inflect->statsbombpy) (4.4.1)
# Requirement already satisfied: numpy<2,>=1.22.4 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from pandas->statsbombpy) (1.23.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from pandas->statsbombpy) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from pandas->statsbombpy) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from pandas->statsbombpy) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from requests->statsbombpy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from requests->statsbombpy) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from requests->statsbombpy) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from requests->statsbombpy) (2023.11.17)
# Requirement already satisfied: attrs>=21.2 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from requests-cache->statsbombpy) (23.1.0)
# Requirement already satisfied: cattrs>=22.2 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from requests-cache->statsbombpy) (24.1.2)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from requests-cache->statsbombpy) (4.0.0)
# Requirement already satisfied: url-normalize>=1.4 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from requests-cache->statsbombpy) (1.4.3)
# Requirement already satisfied: exceptiongroup>=1.1.1 in c:\users\germán llorente\appdata\roaming\python\python39\site-packages (from cattrs>=22.2->requests-cache->statsbombpy) (1.2.0)
# Requirement already satisfied: typing-extensions!=4.6.3,>=4.1.0 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from cattrs>=22.2->requests-cache->statsbombpy) (4.12.2)
# Requirement already satisfied: six>=1.5 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from python-dateutil>=2.8.2->pandas->statsbombpy) (1.16.0)
# Requirement already satisfied: importlib-metadata>=3.6 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from typeguard>=4.0.1->inflect->statsbombpy) (7.0.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from importlib-metadata>=3.6->typeguard>=4.0.1->inflect->statsbombpy) (3.17.0)
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: mplsoccer in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (1.4.0)
# Requirement already satisfied: matplotlib>=3.6 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from mplsoccer) (3.8.2)
# Requirement already satisfied: numpy in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from mplsoccer) (1.23.2)
# Requirement already satisfied: pandas in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from mplsoccer) (2.2.0)
# Requirement already satisfied: pillow in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from mplsoccer) (10.1.0)
# Requirement already satisfied: requests in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from mplsoccer) (2.31.0)
# Requirement already satisfied: scipy in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from mplsoccer) (1.11.4)
# Requirement already satisfied: seaborn in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from mplsoccer) (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.6->mplsoccer) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.6->mplsoccer) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.6->mplsoccer) (4.46.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.6->mplsoccer) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.6->mplsoccer) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.6->mplsoccer) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.6->mplsoccer) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.6->mplsoccer) (6.1.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from pandas->mplsoccer) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from pandas->mplsoccer) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from requests->mplsoccer) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from requests->mplsoccer) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from requests->mplsoccer) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from requests->mplsoccer) (2023.11.17)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from importlib-resources>=3.2.0->matplotlib>=3.6->mplsoccer) (3.17.0)
# Requirement already satisfied: six>=1.5 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.6->mplsoccer) (1.16.0)
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: highlight_text in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (0.2)
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: fuzzywuzzy[speedup] in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (0.18.0)
# Requirement already satisfied: python-levenshtein>=0.12 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from fuzzywuzzy[speedup]) (0.27.1)
# Requirement already satisfied: Levenshtein==0.27.1 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from python-levenshtein>=0.12->fuzzywuzzy[speedup]) (0.27.1)
# Requirement already satisfied: rapidfuzz<4.0.0,>=3.9.0 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from Levenshtein==0.27.1->python-levenshtein>=0.12->fuzzywuzzy[speedup]) (3.12.2)
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: rapidfuzz in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (3.12.2)
# Requirement already satisfied: pandas in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (2.2.0)
# Requirement already satisfied: numpy<2,>=1.22.4 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from pandas) (1.23.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from funciones_analisis import *
from statsbombpy import sb
import pandas as pd
from mplsoccer import VerticalPitch, Pitch
from highlight_text import ax_text, fig_text
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap
import matplotlib.patheffects as path_effects
import seaborn as sns
from rapidfuzz import process, fuzz

# %%
free_comps = sb.competitions()

free_comps
# Out:
#     competition_id  season_id   country_name        competition_name  \
# 0                9        281        Germany           1. Bundesliga
# 1                9         27        Germany           1. Bundesliga
# 2             1267        107         Africa  African Cup of Nations
# 3               16          4         Europe        Champions League
# 4               16          1         Europe        Champions League
# ..             ...        ...            ...                     ...
# 69              55         43         Europe               UEFA Euro
# 70              35         75         Europe      UEFA Europa League
# 71              53        106         Europe       UEFA Women's Euro
# 72              72        107  International       Women's World Cup
# 73              72         30  International       Women's World Cup
#
#    competition_gender  competition_youth  competition_international  \
# 0                male              False                      False
# 1                male              False                      False
# 2                male              False                       True
# 3                male              False                      False
# 4                male              False                      False
# ..                ...                ...                        ...
# 69               male              False                       True
# 70               male              False                      False
# 71             female              False                       True
# 72             female              False                       True
# 73             female              False                       True
#
#    season_name               match_updated           match_updated_360  \
# 0    2023/2024  2024-07-15T14:15:54.671676  2024-07-15T14:17:00.877356
# 1    2015/2016  2024-05-19T11:11:14.192381                        None
# 2         2023  2024-06-13T07:51:02.452825                        None
# 3    2018/2019  2024-06-12T07:44:38.559714     2021-06-13T16:17:31.694
# 4    2017/2018  2024-02-13T02:35:28.134882     2021-06-13T16:17:31.694
# ..         ...                         ...                         ...
# 69        2020  2024-04-16T12:44:40.558402  2024-04-16T12:47:18.505110
# 70   1988/1989  2024-02-12T14:45:05.702250     2021-06-13T16:17:31.694
# 71        2022  2024-02-13T13:27:17.178263  2024-02-13T13:30:52.820588
# 72        2023  2024-07-14T16:59:48.469596  2024-07-14T17:01:38.887279
# 73        2019  2024-02-13T09:41:26.379767     2021-06-13T16:17:31.694
#
#            match_available_360             match_available
# 0   2024-07-15T14:17:00.877356  2024-07-15T14:15:54.671676
# 1                         None  2024-05-19T11:11:14.192381
# 2                         None  2024-06-13T07:51:02.452825
# 3                         None  2024-06-12T07:44:38.559714
# 4                         None  2024-02-13T02:35:28.134882
# ..                         ...                         ...
# 69  2024-04-16T12:47:18.505110  2024-04-16T12:44:40.558402
# 70                        None  2024-02-12T14:45:05.702250
# 71  2024-02-13T13:30:52.820588  2024-02-13T13:27:17.178263
# 72  2024-07-14T17:01:38.887279  2024-07-14T16:59:48.469596
# 73                        None  2024-02-13T09:41:26.379767
#
# [74 rows x 12 columns]

# %%
seriea_16 = sb.matches(competition_id=12, season_id=27)

# %%
seriea_16 = ordenar_partidos_cronologicamente(seriea_16)

seriea_16
# Out:
#      match_id  match_date      kick_off      competition     season  \
# 0     3878541  2015-08-22  18:00:00.000  Italy - Serie A  2015/2016
# 1     3878540  2015-08-22  20:45:00.000  Italy - Serie A  2015/2016
# 2     3878548  2015-08-23  18:00:00.000  Italy - Serie A  2015/2016
# 3     3878547  2015-08-23  20:45:00.000  Italy - Serie A  2015/2016
# 4     3878546  2015-08-23  20:45:00.000  Italy - Serie A  2015/2016
# ..        ...         ...           ...              ...        ...
# 375   3879873  2016-05-15  18:00:00.000  Italy - Serie A  2015/2016
# 376   3879876  2016-05-15  18:00:00.000  Italy - Serie A  2015/2016
# 377   3879871  2016-05-15  20:45:00.000  Italy - Serie A  2015/2016
# 378   3879874  2016-05-15  20:45:00.000  Italy - Serie A  2015/2016
# 379   3879875  2016-05-15  20:45:00.000  Italy - Serie A  2015/2016
#
#          home_team      away_team  home_score  away_score match_status  ...  \
# 0    Hellas Verona        AS Roma           1           1    available  ...
# 1            Lazio        Bologna           2           1    available  ...
# 2         Juventus        Udinese           0           1    available  ...
# 3        Frosinone         Torino           1           2    available  ...
# 4         Sassuolo         Napoli           2           1    available  ...
# ..             ...            ...         ...         ...          ...  ...
# 375         Empoli         Torino           2           1    available  ...
# 376          Genoa       Atalanta           1           2    available  ...
# 377        Udinese          Carpi           1           2    available  ...
# 378          Lazio     Fiorentina           2           4    available  ...
# 379        Palermo  Hellas Verona           3           2    available  ...
#
#     match_week competition_stage                              stadium  \
# 0            1    Regular Season       Stadio Marc''Antonio Bentegodi
# 1            1    Regular Season                     Estadio Olímpico
# 2            1    Regular Season                Allianz Stadium    \t
# 3            1    Regular Season               Stadio Comunale Matusa
# 4            1    Regular Season  MAPEI Stadium - Città del Tricolore
# ..         ...               ...                                  ...
# 375         38    Regular Season              Stadio Carlo Castellani
# 376         38    Regular Season       Stadio Comunale Luigi Ferraris
# 377         38    Regular Season                          Dacia Arena
# 378         38    Regular Season                     Estadio Olímpico
# 379         38    Regular Season                 Stadio Renzo Barbera
#
#                     referee                              home_managers  \
# 0               Marco Guida  Rafael Márquez Álvarez, Andrea Mandorlini
# 1           Gianluca Rocchi                              Stefano Pioli
# 2    Paolo Silvio Mazzoleni                       Massimiliano Allegri
# 3                Luca Banti                           Roberto Stellone
# 4            Daniele Doveri                       Eusebio Di Francesco
# ..                      ...                                        ...
# 375    Francesco Paolo Saia                            Marco Giampaolo
# 376      Gianluca Aureliano                       Gian Piero Gasperini
# 377  Paolo Silvio Mazzoleni                             Luigi De Canio
# 378    Gianluca Manganiello                             Simone Inzaghi
# 379     Massimiliano Irrati                          Davide Ballardini
#
#                       away_managers data_version shot_fidelity_version  \
# 0                       Rudi Garcia        1.1.0                     2
# 1                       Delio Rossi         None                  None
# 2                Stefano Colantuono        1.1.0                     2
# 3              Gian Piero Ventura\t        1.1.0                     2
# 4                    Maurizio Sarri        1.1.0                     2
# ..                              ...          ...                   ...
# 375            Gian Piero Ventura\t        1.1.0                     2
# 376                    Edoardo Reja        1.1.0                     2
# 377                Fabrizio Castori        1.1.0                     2
# 378  Paulo Manuel Carvalho de Sousa        1.1.0                     2
# 379                   Luigi Delneri        1.1.0                     2
#
#     xy_fidelity_version          fecha_hora
# 0                     2 2015-08-22 18:00:00
# 1                  None 2015-08-22 20:45:00
# 2                     2 2015-08-23 18:00:00
# 3                     2 2015-08-23 20:45:00
# 4                     2 2015-08-23 20:45:00
# ..                  ...                 ...
# 375                   2 2016-05-15 18:00:00
# 376                   2 2016-05-15 18:00:00
# 377                   2 2016-05-15 20:45:00
# 378                   2 2016-05-15 20:45:00
# 379                   2 2016-05-15 20:45:00
#
# [380 rows x 23 columns]

# %%
# Lista para guardar DataFrames de eventos
eventos_lista = []

# Descargar eventos de cada partido
for match_id in seriea_16['match_id']:

        eventos = sb.events(match_id=match_id)
        eventos['match_id'] = match_id  # Añadir identificador de partido
        eventos_lista.append(eventos)


# Unir todos los DataFrames en uno solo
eventos_seriea_16 = pd.concat(eventos_lista, ignore_index=True)

# Guardar como archivo CSV
#df_eventos.to_csv('eventos_seriea_2016.csv', index=False)

# %%
# Asegúrate de ejecutar esto antes de inspeccionar columnas
pd.set_option('display.max_columns', None)

# %%
# Convierte a lista y muestra tú mismo

# Mostrar columnas en orden alfabético, una por línea
for col in sorted(eventos_seriea_16.columns):
    print(col)
# Out:
# 50_50
# bad_behaviour_card
# ball_receipt_outcome
# ball_recovery_offensive
# ball_recovery_recovery_failure
# block_deflection
# block_offensive
# block_save_block
# carry_end_location
# clearance_aerial_won
# clearance_body_part
# clearance_head
# clearance_left_foot
# clearance_other
# clearance_right_foot
# counterpress
# dribble_no_touch
# dribble_nutmeg
# dribble_outcome
# dribble_overrun
# duel_outcome
# duel_type
# duration
# foul_committed_advantage
# foul_committed_card
# foul_committed_offensive
# foul_committed_penalty
# foul_committed_type
# foul_won_advantage
# foul_won_defensive
# foul_won_penalty
# goalkeeper_body_part
# goalkeeper_end_location
# goalkeeper_lost_in_play
# goalkeeper_lost_out
# goalkeeper_outcome
# goalkeeper_position
# goalkeeper_punched_out
# goalkeeper_shot_saved_off_target
# goalkeeper_shot_saved_to_post
# goalkeeper_success_in_play
# goalkeeper_technique
# goalkeeper_type
# half_start_late_video_start
# id
# index
# injury_stoppage_in_chain
# interception_outcome
# location
# match_id
# minute
# miscontrol_aerial_won
# off_camera
# out
# pass_aerial_won
# pass_angle
# pass_assisted_shot_id
# pass_body_part
# pass_cross
# pass_cut_back
# pass_deflected
# pass_end_location
# pass_goal_assist
# pass_height
# pass_inswinging
# pass_length
# pass_miscommunication
# pass_no_touch
# pass_outcome
# pass_outswinging
# pass_recipient
# pass_recipient_id
# pass_shot_assist
# pass_straight
# pass_switch
# pass_technique
# pass_through_ball
# pass_type
# period
# play_pattern
# player
# player_id
# player_off_permanent
# position
# possession
# possession_team
# possession_team_id
# related_events
# second
# shot_aerial_won
# shot_body_part
# shot_deflected
# shot_end_location
# shot_first_time
# shot_follows_dribble
# shot_freeze_frame
# shot_key_pass_id
# shot_one_on_one
# shot_open_goal
# shot_outcome
# shot_redirect
# shot_saved_off_target
# shot_saved_to_post
# shot_statsbomb_xg
# shot_technique
# shot_type
# substitution_outcome
# substitution_outcome_id
# substitution_replacement
# substitution_replacement_id
# tactics
# team
# team_id
# timestamp
# type
# under_pressure

# %%
eventos_seriea_16.head()
# Out:
#   50_50 ball_receipt_outcome ball_recovery_offensive  \
# 0   NaN                  NaN                     NaN
# 1   NaN                  NaN                     NaN
# 2   NaN                  NaN                     NaN
# 3   NaN                  NaN                     NaN
# 4   NaN                  NaN                     NaN
#
#   ball_recovery_recovery_failure block_offensive block_save_block  \
# 0                            NaN             NaN              NaN
# 1                            NaN             NaN              NaN
# 2                            NaN             NaN              NaN
# 3                            NaN             NaN              NaN
# 4                            NaN             NaN              NaN
#
#   carry_end_location clearance_aerial_won clearance_body_part clearance_head  \
# 0                NaN                  NaN                 NaN            NaN
# 1                NaN                  NaN                 NaN            NaN
# 2                NaN                  NaN                 NaN            NaN
# 3                NaN                  NaN                 NaN            NaN
# 4                NaN                  NaN                 NaN            NaN
#
#   clearance_left_foot clearance_other clearance_right_foot counterpress  \
# 0                 NaN             NaN                  NaN          NaN
# 1                 NaN             NaN                  NaN          NaN
# 2                 NaN             NaN                  NaN          NaN
# 3                 NaN             NaN                  NaN          NaN
# 4                 NaN             NaN                  NaN          NaN
#
#   dribble_nutmeg dribble_outcome dribble_overrun duel_outcome duel_type  \
# 0            NaN             NaN             NaN          NaN       NaN
# 1            NaN             NaN             NaN          NaN       NaN
# 2            NaN             NaN             NaN          NaN       NaN
# 3            NaN             NaN             NaN          NaN       NaN
# 4            NaN             NaN             NaN          NaN       NaN
#
#    duration foul_committed_advantage foul_committed_card foul_won_advantage  \
# 0       0.0                      NaN                 NaN                NaN
# 1       0.0                      NaN                 NaN                NaN
# 2       0.0                      NaN                 NaN                NaN
# 3       0.0                      NaN                 NaN                NaN
# 4       0.0                      NaN                 NaN                NaN
#
#   foul_won_defensive goalkeeper_body_part goalkeeper_end_location  \
# 0                NaN                  NaN                     NaN
# 1                NaN                  NaN                     NaN
# 2                NaN                  NaN                     NaN
# 3                NaN                  NaN                     NaN
# 4                NaN                  NaN                     NaN
#
#   goalkeeper_outcome goalkeeper_position goalkeeper_shot_saved_to_post  \
# 0                NaN                 NaN                           NaN
# 1                NaN                 NaN                           NaN
# 2                NaN                 NaN                           NaN
# 3                NaN                 NaN                           NaN
# 4                NaN                 NaN                           NaN
#
#   goalkeeper_technique goalkeeper_type                                    id  \
# 0                  NaN             NaN  9ca545fc-0e43-46fc-acdd-ea6111070de3
# 1                  NaN             NaN  2713651d-0778-4b46-bae2-30da75998b72
# 2                  NaN             NaN  d567a603-89e5-4b1d-bd9e-cf0f1ae0abed
# 3                  NaN             NaN  7a4151df-9487-4491-80e4-e1b41ab1587b
# 4                  NaN             NaN  4dd8bb12-f5d9-408a-ab2e-d9a68afcb2c4
#
#    index interception_outcome location  match_id  minute  \
# 0      1                  NaN      NaN   3878541       0
# 1      2                  NaN      NaN   3878541       0
# 2      3                  NaN      NaN   3878541       0
# 3      4                  NaN      NaN   3878541       0
# 4   1614                  NaN      NaN   3878541      45
#
#   miscontrol_aerial_won off_camera  out pass_aerial_won  pass_angle  \
# 0                   NaN        NaN  NaN             NaN         NaN
# 1                   NaN        NaN  NaN             NaN         NaN
# 2                   NaN        NaN  NaN             NaN         NaN
# 3                   NaN        NaN  NaN             NaN         NaN
# 4                   NaN        NaN  NaN             NaN         NaN
#
#   pass_assisted_shot_id pass_body_part pass_cross pass_cut_back  \
# 0                   NaN            NaN        NaN           NaN
# 1                   NaN            NaN        NaN           NaN
# 2                   NaN            NaN        NaN           NaN
# 3                   NaN            NaN        NaN           NaN
# 4                   NaN            NaN        NaN           NaN
#
#   pass_end_location pass_goal_assist pass_height pass_inswinging  pass_length  \
# 0               NaN              NaN         NaN             NaN          NaN
# 1               NaN              NaN         NaN             NaN          NaN
# 2               NaN              NaN         NaN             NaN          NaN
# 3               NaN              NaN         NaN             NaN          NaN
# 4               NaN              NaN         NaN             NaN          NaN
#
#   pass_miscommunication pass_outcome pass_outswinging pass_recipient  \
# 0                   NaN          NaN              NaN            NaN
# 1                   NaN          NaN              NaN            NaN
# 2                   NaN          NaN              NaN            NaN
# 3                   NaN          NaN              NaN            NaN
# 4                   NaN          NaN              NaN            NaN
#
#    pass_recipient_id pass_shot_assist pass_straight pass_switch  \
# 0                NaN              NaN           NaN         NaN
# 1                NaN              NaN           NaN         NaN
# 2                NaN              NaN           NaN         NaN
# 3                NaN              NaN           NaN         NaN
# 4                NaN              NaN           NaN         NaN
#
#   pass_technique pass_through_ball pass_type  period  play_pattern player  \
# 0            NaN               NaN       NaN       1  Regular Play    NaN
# 1            NaN               NaN       NaN       1  Regular Play    NaN
# 2            NaN               NaN       NaN       1  Regular Play    NaN
# 3            NaN               NaN       NaN       1  Regular Play    NaN
# 4            NaN               NaN       NaN       2  Regular Play    NaN
#
#    player_id position  possession possession_team  possession_team_id  \
# 0        NaN      NaN           1   Hellas Verona                 226
# 1        NaN      NaN           1   Hellas Verona                 226
# 2        NaN      NaN           1   Hellas Verona                 226
# 3        NaN      NaN           1   Hellas Verona                 226
# 4        NaN      NaN          90         AS Roma                 229
#
#                            related_events  second shot_aerial_won  \
# 0                                     NaN       0             NaN
# 1                                     NaN       0             NaN
# 2  [7a4151df-9487-4491-80e4-e1b41ab1587b]       0             NaN
# 3  [d567a603-89e5-4b1d-bd9e-cf0f1ae0abed]       0             NaN
# 4  [e4358511-9335-4d60-b45a-f20355138e69]       0             NaN
#
#   shot_body_part shot_end_location shot_first_time shot_freeze_frame  \
# 0            NaN               NaN             NaN               NaN
# 1            NaN               NaN             NaN               NaN
# 2            NaN               NaN             NaN               NaN
# 3            NaN               NaN             NaN               NaN
# 4            NaN               NaN             NaN               NaN
#
#   shot_key_pass_id shot_one_on_one shot_outcome shot_saved_to_post  \
# 0              NaN             NaN          NaN                NaN
# 1              NaN             NaN          NaN                NaN
# 2              NaN             NaN          NaN                NaN
# 3              NaN             NaN          NaN                NaN
# 4              NaN             NaN          NaN                NaN
#
#    shot_statsbomb_xg shot_technique shot_type substitution_outcome  \
# 0                NaN            NaN       NaN                  NaN
# 1                NaN            NaN       NaN                  NaN
# 2                NaN            NaN       NaN                  NaN
# 3                NaN            NaN       NaN                  NaN
# 4                NaN            NaN       NaN                  NaN
#
#    substitution_outcome_id substitution_replacement  \
# 0                      NaN                      NaN
# 1                      NaN                      NaN
# 2                      NaN                      NaN
# 3                      NaN                      NaN
# 4                      NaN                      NaN
#
#    substitution_replacement_id  \
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
#
#                                              tactics           team  team_id  \
# 0  {'formation': 433, 'lineup': [{'player': {'id'...  Hellas Verona      226
# 1  {'formation': 433, 'lineup': [{'player': {'id'...        AS Roma      229
# 2                                                NaN  Hellas Verona      226
# 3                                                NaN        AS Roma      229
# 4                                                NaN        AS Roma      229
#
#       timestamp         type under_pressure dribble_no_touch  \
# 0  00:00:00.000  Starting XI            NaN              NaN
# 1  00:00:00.000  Starting XI            NaN              NaN
# 2  00:00:00.000   Half Start            NaN              NaN
# 3  00:00:00.000   Half Start            NaN              NaN
# 4  00:00:00.000   Half Start            NaN              NaN
#
#   foul_committed_offensive foul_committed_type injury_stoppage_in_chain  \
# 0                      NaN                 NaN                      NaN
# 1                      NaN                 NaN                      NaN
# 2                      NaN                 NaN                      NaN
# 3                      NaN                 NaN                      NaN
# 4                      NaN                 NaN                      NaN
#
#   pass_no_touch block_deflection goalkeeper_punched_out pass_deflected  \
# 0           NaN              NaN                    NaN            NaN
# 1           NaN              NaN                    NaN            NaN
# 2           NaN              NaN                    NaN            NaN
# 3           NaN              NaN                    NaN            NaN
# 4           NaN              NaN                    NaN            NaN
#
#   shot_deflected shot_open_goal bad_behaviour_card foul_committed_penalty  \
# 0            NaN            NaN                NaN                    NaN
# 1            NaN            NaN                NaN                    NaN
# 2            NaN            NaN                NaN                    NaN
# 3            NaN            NaN                NaN                    NaN
# 4            NaN            NaN                NaN                    NaN
#
#   foul_won_penalty goalkeeper_shot_saved_off_target shot_saved_off_target  \
# 0              NaN                              NaN                   NaN
# 1              NaN                              NaN                   NaN
# 2              NaN                              NaN                   NaN
# 3              NaN                              NaN                   NaN
# 4              NaN                              NaN                   NaN
#
#   half_start_late_video_start shot_redirect player_off_permanent  \
# 0                         NaN           NaN                  NaN
# 1                         NaN           NaN                  NaN
# 2                         NaN           NaN                  NaN
# 3                         NaN           NaN                  NaN
# 4                         NaN           NaN                  NaN
#
#   goalkeeper_success_in_play goalkeeper_lost_in_play shot_follows_dribble  \
# 0                        NaN                     NaN                  NaN
# 1                        NaN                     NaN                  NaN
# 2                        NaN                     NaN                  NaN
# 3                        NaN                     NaN                  NaN
# 4                        NaN                     NaN                  NaN
#
#   goalkeeper_lost_out
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN

# %%
def perfil_jugadores(df_eventos):
    # Eliminar eventos sin jugador
    df = df_eventos.dropna(subset=['player_id', 'player']).copy()

    # Lista para guardar los resultados
    perfiles = []

    # Agrupar por jugador
    for player_id, grupo in df.groupby('player_id'):
        nombre = grupo['player'].iloc[-1]
        ultimo_equipo = grupo['team'].dropna().iloc[-1] if 'team' in grupo else None
        ultimo_team_id = grupo['team_id'].dropna().iloc[-1] if 'team_id' in grupo else None
        posiciones = grupo['position'].dropna().unique().tolist()
        partidos_jugados = grupo['match_id'].nunique()  # contar partidos únicos

        perfiles.append({
            'player_id': int(player_id),
            'player': nombre,
            'ultimo_equipo': ultimo_equipo,
            'ultimo_team_id': ultimo_team_id,
            'posiciones': posiciones,
            'partidos_jugados': partidos_jugados
        })

    return pd.DataFrame(perfiles)


perfiles_jugadores = perfil_jugadores(eventos_seriea_16)

# %%
perfiles_jugadores
# Out:
#      player_id                    player ultimo_equipo  ultimo_team_id  \
# 0         3034                Kamil Glik        Torino             241
# 1         3103             Milan Biševac         Lazio             236
# 2         3112  Anton Ciprian Tătărușanu    Fiorentina             239
# 3         3125    Danilo Fernando Avelar        Torino             241
# 4         3145          Keita Baldé Diao         Lazio             236
# ..         ...                       ...           ...             ...
# 546     387832           Filippo Porcari         Carpi            1683
# 547     387847        Leonardo Blanchard     Frosinone             291
# 548     390310          Lorenzo Di Livio       AS Roma             229
# 549     398941              Vasyl Pryyma     Frosinone             291
# 550     399299            Kévin Constant       Bologna             240
#
#                                             posiciones  partidos_jugados
# 0    [Center Back, Right Center Back, Left Center B...                33
# 1                                  [Right Center Back]                11
# 2                                         [Goalkeeper]                37
# 3                          [Left Wing Back, Left Back]                 6
# 4    [Center Forward, Left Wing, Right Wing, Left M...                31
# ..                                                 ...               ...
# 546  [Right Defensive Midfield, Center Defensive Mi...                 4
# 547  [Left Center Back, Center Back, Right Center B...                28
# 548                                       [Right Wing]                 1
# 549          [Left Center Back, Right Back, Left Back]                 5
# 550                             [Left Back, Left Wing]                 7
#
# [551 rows x 6 columns]

# %%
perfiles_jugadores['player_id'] = perfiles_jugadores['player_id'].astype(int)
perfiles_jugadores
# Out:
#      player_id                    player ultimo_equipo  ultimo_team_id  \
# 0         3034                Kamil Glik        Torino             241
# 1         3103             Milan Biševac         Lazio             236
# 2         3112  Anton Ciprian Tătărușanu    Fiorentina             239
# 3         3125    Danilo Fernando Avelar        Torino             241
# 4         3145          Keita Baldé Diao         Lazio             236
# ..         ...                       ...           ...             ...
# 546     387832           Filippo Porcari         Carpi            1683
# 547     387847        Leonardo Blanchard     Frosinone             291
# 548     390310          Lorenzo Di Livio       AS Roma             229
# 549     398941              Vasyl Pryyma     Frosinone             291
# 550     399299            Kévin Constant       Bologna             240
#
#                                             posiciones  partidos_jugados
# 0    [Center Back, Right Center Back, Left Center B...                33
# 1                                  [Right Center Back]                11
# 2                                         [Goalkeeper]                37
# 3                          [Left Wing Back, Left Back]                 6
# 4    [Center Forward, Left Wing, Right Wing, Left M...                31
# ..                                                 ...               ...
# 546  [Right Defensive Midfield, Center Defensive Mi...                 4
# 547  [Left Center Back, Center Back, Right Center B...                28
# 548                                       [Right Wing]                 1
# 549          [Left Center Back, Right Back, Left Back]                 5
# 550                             [Left Back, Left Wing]                 7
#
# [551 rows x 6 columns]

# %%
output_path = 'datos/seriea16_jugadores.csv'
perfiles_jugadores.to_csv(output_path, index=False)

# %%
def obtener_datos_generales_equipos(df):
    """Extrae team y team_id únicos presentes en el DataFrame."""
    return df[['team_id', 'team']].drop_duplicates().reset_index(drop=True)

# %%
equipos_df = obtener_datos_generales_equipos(eventos_seriea_16)
print(equipos_df)
# Out:
#     team_id           team
# 0       226  Hellas Verona
# 1       229        AS Roma
# 2       236          Lazio
# 3       240        Bologna
# 4       224       Juventus
# 5       230        Udinese
# 6       291      Frosinone
# 7       241         Torino
# 8       232       Sassuolo
# 9       227         Napoli
# 10      290         Empoli
# 11      231         Chievo
# 12     2256        Palermo
# 13      233          Genoa
# 14      238    Inter Milan
# 15      228       Atalanta
# 16      239     Fiorentina
# 17      243       AC Milan
# 18      234      Sampdoria
# 19     1683          Carpi

# %%
equipos_df.to_csv('datos/seriea16_equipos.csv', index=False)

# %%
from rapidfuzz import process, fuzz
import pandas as pd

def hacer_matching_aproximado(base_df, columna_base, df_referencia, columna_referencia, umbral=85):
    """
    Realiza un emparejamiento difuso (fuzzy matching) entre dos listas de nombres.

    Parámetros:
    - base_df: DataFrame con los nombres originales (por ejemplo, nombres en statsbomb).
    - columna_base: columna en base_df con los nombres a emparejar (ej: 'team', 'player').
    - df_referencia: DataFrame con los nombres de referencia (por ejemplo, datos económicos).
    - columna_referencia: columna en df_referencia con los nombres correctos (ej: 'team').
    - umbral: valor mínimo de similitud para aceptar automáticamente (default = 85).

    Devuelve:
    - DataFrame con columnas: nombre original, nombre emparejado, score, revisar (True/False)
    """
    nombres_base = base_df[columna_base].unique()
    nombres_ref = df_referencia[columna_referencia].tolist()

    resultados = []

    for nombre in nombres_base:
        mejor_match, score, _ = process.extractOne(nombre, nombres_ref, scorer=fuzz.token_sort_ratio)
        revisar = score < umbral
        resultados.append({
            columna_base: nombre,
            f"{columna_referencia}_match": mejor_match,
            "score": score,
            "revisar": revisar
        })

    return pd.DataFrame(resultados)

# %%
# Ruta al archivo desde tu script
df_economicos = pd.read_csv("datos/fifa_economicos/datos_economicos_serie_a.csv")

# %%
# 1. Aplicar fuzzy matching
df_matching = hacer_matching_aproximado(
    base_df=equipos_df,
    columna_base='team',
    df_referencia=df_economicos,
    columna_referencia='team',
    umbral=85
)

# 2. Hacer el merge con los datos económicos
equipos_matcheados = equipos_df.merge(df_matching, on='team')
equipos_completos = equipos_matcheados.merge(
    df_economicos,
    left_on='team_match',
    right_on='team',
    how='left',
    suffixes=('', '_econ')
)

# %%
equipos_completos
# Out:
#     team_id           team     team_match       score  revisar      team_econ  \
# 0       226  Hellas Verona  Hellas Verona  100.000000    False  Hellas Verona
# 1       229        AS Roma        AS Roma  100.000000    False        AS Roma
# 2       236          Lazio          Lazio  100.000000    False          Lazio
# 3       240        Bologna        Bologne   85.714286    False        Bologne
# 4       224       Juventus       Juventus  100.000000    False       Juventus
# 5       230        Udinese        Udinese  100.000000    False        Udinese
# 6       291      Frosinone      Frosinone  100.000000    False      Frosinone
# 7       241         Torino         Torino  100.000000    False         Torino
# 8       232       Sassuolo       Sassuolo  100.000000    False       Sassuolo
# 9       227         Napoli         Napoli  100.000000    False         Napoli
# 10      290         Empoli         Empoli  100.000000    False         Empoli
# 11      231         Chievo  Chievo Verona   63.157895     True  Chievo Verona
# 12     2256        Palermo        Palermo  100.000000    False        Palermo
# 13      233          Genoa          Genoa  100.000000    False          Genoa
# 14      238    Inter Milan          Inter   62.500000     True          Inter
# 15      228       Atalanta       Atalanta  100.000000    False       Atalanta
# 16      239     Fiorentina     Fiorentina  100.000000    False     Fiorentina
# 17      243       AC Milan          Milan   76.923077     True          Milan
# 18      234      Sampdoria      Sampdoria  100.000000    False      Sampdoria
# 19     1683          Carpi          Carpi  100.000000    False          Carpi
#
#     presupuesto_fichajes  presupuesto_sueldos
# 0                5500000               862000
# 1               34000000              2290000
# 2               17500000              2048000
# 3               12000000               604000
# 4               60000000              3309000
# 5               17500000               985000
# 6                1800000               181000
# 7               14000000              1131000
# 8               10000000               683000
# 9               27500000              2251000
# 10               3400000               493000
# 11               4600000               851000
# 12               9000000               641000
# 13              12000000              1060000
# 14              37500000              2132000
# 15               7000000               986000
# 16              19500000              1257000
# 17              40000000              2269000
# 18              10500000               850000
# 19               1900000               597000

# %%
columnas_a_eliminar = ['team_match', 'score', 'revisar', 'team_econ']
laliga_limpio = equipos_completos.drop(columns=columnas_a_eliminar)

# %%
laliga_limpio.to_csv("datos/seriea16_equipos.csv", index=False)

# %%
# 1. Cargar los datasets
df_jugadores = pd.read_csv("datos/seriea16_jugadores.csv")      # StatsBomb
df_fifa = pd.read_csv("datos/fifa16.csv")     

# 2. Filtrar jugadores de LaLiga en FIFA
df_jugadores_fifa_seriea = df_fifa[df_fifa['league_name'] == "Italian Serie A"].copy()
# Out:
# C:\Users\Germán Llorente\AppData\Local\Temp\ipykernel_23748\3320354027.py:3: DtypeWarning: Columns (104) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_fifa = pd.read_csv("datos/fifa16.csv")

# %%
df_jugadores_fifa_seriea.head()
# Out:
#     sofifa_id                                         player_url  \
# 12     138956  https://sofifa.com/player/138956/giorgio-chiel...
# 38     195864  https://sofifa.com/player/195864/paul-pogba/16...
# 51       1179  https://sofifa.com/player/1179/gianluigi-buffo...
# 58     137186  https://sofifa.com/player/137186/andrea-barzag...
# 62     167664  https://sofifa.com/player/167664/gonzalo-higua...
#
#       short_name                long_name player_positions  overall  \
# 12  G. Chiellini        Giorgio Chiellini               CB       87
# 38      P. Pogba               Paul Pogba               CM       86
# 51     G. Buffon         Gianluigi Buffon               GK       84
# 58   A. Barzagli          Andrea Barzagli               CB       84
# 62    G. Higuaín  Gonzalo Gerardo Higuaín               ST       84
#
#     potential   value_eur  wage_eur  age         dob  height_cm  weight_kg  \
# 12         87  32500000.0  190000.0   30  1984-08-14        186         76
# 38         92  53000000.0  180000.0   22  1993-03-15        188         80
# 51         84   9000000.0  130000.0   37  1978-01-28        191         83
# 58         84   9000000.0  120000.0   34  1981-05-08        186         79
# 62         86  34500000.0  190000.0   27  1987-12-10        184         82
#
#     club_team_id club_name      league_name  league_level club_position  \
# 12          45.0  Juventus  Italian Serie A           1.0           LCB
# 38          45.0  Juventus  Italian Serie A           1.0           LCM
# 51          45.0  Juventus  Italian Serie A           1.0            GK
# 58          45.0  Juventus  Italian Serie A           1.0           SUB
# 62          48.0    Napoli  Italian Serie A           1.0            LS
#
#     club_jersey_number club_loaned_from club_joined  \
# 12                 3.0              NaN  2005-07-01
# 38                10.0              NaN  2012-07-01
# 51                 1.0              NaN  2001-07-01
# 58                15.0              NaN  2011-01-01
# 62                 9.0              NaN  2013-07-27
#
#     club_contract_valid_until  nationality_id nationality_name  \
# 12                     2018.0              27            Italy
# 38                     2019.0              18           France
# 51                     2017.0              27            Italy
# 58                     2016.0              27            Italy
# 62                     2018.0              52        Argentina
#
#     nation_team_id nation_position  nation_jersey_number preferred_foot  \
# 12          1343.0             LCB                   3.0           Left
# 38          1335.0             CAM                  19.0          Right
# 51          1343.0              GK                   1.0          Right
# 58             NaN             NaN                   NaN          Right
# 62          1369.0             SUB                   9.0          Right
#
#     weak_foot  skill_moves  international_reputation      work_rate  \
# 12          2            2                         4       Low/High
# 38          4            4                         4    High/Medium
# 51          2            1                         4  Medium/Medium
# 58          3            2                         3       Low/High
# 62          4            3                         3    High/Medium
#
#            body_type real_face  release_clause_eur  \
# 12     Normal (185+)       Yes                 NaN
# 38       Lean (185+)       Yes                 NaN
# 51     Normal (185+)       Yes                 NaN
# 58     Normal (185+)       Yes                 NaN
# 62  Normal (170-185)       Yes                 NaN
#
#                      player_tags  \
# 12        #Tackling, #Tactician
# 38  #Distance Shooter, #Strength
# 51                           NaN
# 58        #Tackling, #Tactician
# 62                           NaN
#
#                                         player_traits  pace  shooting  \
# 12  Long Throw-in, Avoids Using Weaker Foot, Dives...  77.0      47.0
# 38  Dives Into Tackles (AI), Flair, Long Shot Take...  77.0      80.0
# 51           Leadership, One Club Player, Team Player   NaN       NaN
# 58                           Injury Prone, Leadership  75.0      36.0
# 62                                  Outside Foot Shot  80.0      85.0
#
#     passing  dribbling  defending  physic  attacking_crossing  \
# 12     56.0       58.0       90.0    84.0                  62
# 38     82.0       86.0       74.0    88.0                  76
# 51      NaN        NaN        NaN     NaN                  13
# 58     55.0       59.0       88.0    77.0                  40
# 62     68.0       81.0       22.0    71.0                  72
#
#     attacking_finishing  attacking_heading_accuracy  attacking_short_passing  \
# 12                   34                          84                       57
# 38                   70                          72                       85
# 51                   15                          13                       37
# 58                   26                          76                       65
# 62                   89                          77                       70
#
#     attacking_volleys  skill_dribbling  skill_curve  skill_fk_accuracy  \
# 12                 45               56           60                 31
# 38                 84               88           82                 80
# 51                 17               25           20                 13
# 58                 35               52           50                 31
# 62                 83               82           72                 62
#
#     skill_long_passing  skill_ball_control  movement_acceleration  \
# 12                  65                  53                     75
# 38                  81                  89                     75
# 51                  35                  23                     49
# 58                  65                  65                     73
# 62                  55                  84                     79
#
#     movement_sprint_speed  movement_agility  movement_reactions  \
# 12                     79                65                  80
# 38                     79                75                  86
# 51                     43                55                  76
# 58                     77                61                  80
# 62                     81                72                  83
#
#     movement_balance  power_shot_power  power_jumping  power_stamina  \
# 12                69                79             89             69
# 38                61                91             85             87
# 51                49                20             75             39
# 58                69                51             83             65
# 62                60                84             73             69
#
#     power_strength  power_long_shots  mentality_aggression  \
# 12              89                49                    88
# 38              91                91                    80
# 51              63                13                    38
# 58              83                39                    76
# 62              80                77                    50
#
#     mentality_interceptions  mentality_positioning  mentality_vision  \
# 12                       87                     33                46
# 38                       71                     83                86
# 51                       20                     14                50
# 58                       89                     33                50
# 62                       19                     88                70
#
#     mentality_penalties  mentality_composure  defending_marking_awareness  \
# 12                   50                  NaN                           91
# 38                   76                  NaN                           71
# 51                   22                  NaN                           10
# 58                   50                  NaN                           89
# 62                   74                  NaN                           15
#
#     defending_standing_tackle  defending_sliding_tackle  goalkeeping_diving  \
# 12                         91                        91                   3
# 38                         77                        83                   5
# 51                         11                        11                  85
# 58                         89                        89                   4
# 62                         15                        10                   5
#
#     goalkeeping_handling  goalkeeping_kicking  goalkeeping_positioning  \
# 12                     3                    2                        4
# 38                     6                    2                        4
# 51                    79                   71                       89
# 58                     2                    4                        2
# 62                    12                    7                        5
#
#     goalkeeping_reflexes  goalkeeping_speed    ls    st    rs    lw    lf  \
# 12                     3                NaN  59+2  59+2  59+2  56+2  55+2
# 38                     3                NaN  82+2  82+2  82+2  83+2  84+2
# 51                    83               46.0  28+2  28+2  28+2  31+2  31+2
# 58                     4                NaN  54+1  54+1  54+1  54+1  54+1
# 62                    10                NaN  83+1  83+1  83+1  80+1  82+1
#
#       cf    rf    rw   lam   cam   ram    lm   lcm    cm   rcm    rm   lwb  \
# 12  55+2  55+2  56+2  54+2  54+2  54+2  58+2  60+2  60+2  60+2  58+2  75+2
# 38  84+2  84+2  83+2  84+2  84+2  84+2  83+2  84+2  84+2  84+2  83+2  80+2
# 51  31+2  31+2  31+2  34+2  34+2  34+2  33+2  34+2  34+2  34+2  33+2  28+2
# 58  54+1  54+1  54+1  56+1  56+1  56+1  57+1  62+1  62+1  62+1  57+1  73+1
# 62  82+1  82+1  80+1  78+1  78+1  78+1  78+1  68+1  68+1  68+1  78+1  53+1
#
#      ldm   cdm   rdm   rwb    lb   lcb    cb   rcb    rb    gk  \
# 12  75+2  75+2  75+2  75+2  78+2  85+2  85+2  85+2  78+2  12+2
# 38  81+2  81+2  81+2  80+2  79+2  79+2  79+2  79+2  79+2  13+2
# 51  31+2  31+2  31+2  28+2  27+2  27+2  27+2  27+2  27+2  82+2
# 58  76+1  76+1  76+1  73+1  76+1  83+1  83+1  83+1  76+1  12+1
# 62  48+1  48+1  48+1  53+1  49+1  42+1  42+1  42+1  49+1  16+1
#
#                                       player_face_url  \
# 12  https://cdn.sofifa.net/players/138/956/16_120.png
# 38  https://cdn.sofifa.net/players/195/864/16_120.png
# 51  https://cdn.sofifa.net/players/001/179/16_120.png
# 58  https://cdn.sofifa.net/players/137/186/16_120.png
# 62  https://cdn.sofifa.net/players/167/664/16_120.png
#
#                              club_logo_url  \
# 12  https://cdn.sofifa.net/teams/45/60.png
# 38  https://cdn.sofifa.net/teams/45/60.png
# 51  https://cdn.sofifa.net/teams/45/60.png
# 58  https://cdn.sofifa.net/teams/45/60.png
# 62  https://cdn.sofifa.net/teams/48/60.png
#
#                           club_flag_url  \
# 12  https://cdn.sofifa.net/flags/it.png
# 38  https://cdn.sofifa.net/flags/it.png
# 51  https://cdn.sofifa.net/flags/it.png
# 58  https://cdn.sofifa.net/flags/it.png
# 62  https://cdn.sofifa.net/flags/it.png
#
#                              nation_logo_url  \
# 12  https://cdn.sofifa.net/teams/1343/60.png
# 38  https://cdn.sofifa.net/teams/1335/60.png
# 51  https://cdn.sofifa.net/teams/1343/60.png
# 58                                       NaN
# 62  https://cdn.sofifa.net/teams/1369/60.png
#
#                         nation_flag_url
# 12  https://cdn.sofifa.net/flags/it.png
# 38  https://cdn.sofifa.net/flags/fr.png
# 51  https://cdn.sofifa.net/flags/it.png
# 58  https://cdn.sofifa.net/flags/it.png
# 62  https://cdn.sofifa.net/flags/ar.png

# %%
'''
df_jugadores_fifa_laliga['club_name'] = df_jugadores_fifa_laliga['club_name'].replace(
    'RCD Espanyol de Barcelona', 'RCD Espanyol'
)
'''
# Out:
# "\ndf_jugadores_fifa_laliga['club_name'] = df_jugadores_fifa_laliga['club_name'].replace(\n    'RCD Espanyol de Barcelona', 'RCD Espanyol'\n)\n"

# %%
valores_unicos_columna(df_jugadores_fifa_seriea, 'club_name')
# Out:
# array(['Juventus', 'Napoli', 'Inter', 'Roma', 'Lazio', 'AC Milan',
#        'Fiorentina', 'Torino F.C.', 'U.C. Sampdoria', 'Genoa',
#        'U.S. Sassuolo Calcio', 'Udinese Calcio', 'Atalanta', 'Palermo',
#        'Bologna', 'Chievo Verona', 'Hellas Verona', 'Empoli', 'Carpi',
#        'Frosinone'], dtype=object)

# %%
# Obtener valores únicos
equipos_fifa = df_jugadores_fifa_seriea['club_name'].dropna().unique()
equipos_sb = df_jugadores['ultimo_equipo'].dropna().unique()

# Crear diccionario de traducción usando fuzzy matching
equipo_map = {}
for equipo_fifa in equipos_fifa:
    resultado = process.extractOne(equipo_fifa, equipos_sb, scorer=fuzz.token_sort_ratio)
    if resultado:
        mejor_match, score, _ = resultado
        if score >= 50:  # Solo si es un buen match
            equipo_map[equipo_fifa] = mejor_match
        else:
            equipo_map[equipo_fifa] = None  # Marca para revisar manualmente
    else:
        equipo_map[equipo_fifa] = None

# Aplicar la traducción a todo el dataset FIFA
df_fifa['club_name_original'] = df_fifa['club_name']  # Guardar original por seguridad
df_fifa['club_name'] = df_fifa['club_name'].map(equipo_map)

# %%
# 2. Filtrar jugadores de LaLiga en FIFA
df_jugadores_fifa_seriea = df_fifa[df_fifa['league_name'] == "Italian Serie A"].copy()

#df_jugadores_fifa_laliga['club_name'] = df_jugadores_fifa_laliga['club_name'].fillna('Espanyol')

df_jugadores_fifa_seriea.head(5)
# Out:
#     sofifa_id                                         player_url  \
# 12     138956  https://sofifa.com/player/138956/giorgio-chiel...
# 38     195864  https://sofifa.com/player/195864/paul-pogba/16...
# 51       1179  https://sofifa.com/player/1179/gianluigi-buffo...
# 58     137186  https://sofifa.com/player/137186/andrea-barzag...
# 62     167664  https://sofifa.com/player/167664/gonzalo-higua...
#
#       short_name                long_name player_positions  overall  \
# 12  G. Chiellini        Giorgio Chiellini               CB       87
# 38      P. Pogba               Paul Pogba               CM       86
# 51     G. Buffon         Gianluigi Buffon               GK       84
# 58   A. Barzagli          Andrea Barzagli               CB       84
# 62    G. Higuaín  Gonzalo Gerardo Higuaín               ST       84
#
#     potential   value_eur  wage_eur  age         dob  height_cm  weight_kg  \
# 12         87  32500000.0  190000.0   30  1984-08-14        186         76
# 38         92  53000000.0  180000.0   22  1993-03-15        188         80
# 51         84   9000000.0  130000.0   37  1978-01-28        191         83
# 58         84   9000000.0  120000.0   34  1981-05-08        186         79
# 62         86  34500000.0  190000.0   27  1987-12-10        184         82
#
#     club_team_id club_name      league_name  league_level club_position  \
# 12          45.0  Juventus  Italian Serie A           1.0           LCB
# 38          45.0  Juventus  Italian Serie A           1.0           LCM
# 51          45.0  Juventus  Italian Serie A           1.0            GK
# 58          45.0  Juventus  Italian Serie A           1.0           SUB
# 62          48.0    Napoli  Italian Serie A           1.0            LS
#
#     club_jersey_number club_loaned_from club_joined  \
# 12                 3.0              NaN  2005-07-01
# 38                10.0              NaN  2012-07-01
# 51                 1.0              NaN  2001-07-01
# 58                15.0              NaN  2011-01-01
# 62                 9.0              NaN  2013-07-27
#
#     club_contract_valid_until  nationality_id nationality_name  \
# 12                     2018.0              27            Italy
# 38                     2019.0              18           France
# 51                     2017.0              27            Italy
# 58                     2016.0              27            Italy
# 62                     2018.0              52        Argentina
#
#     nation_team_id nation_position  nation_jersey_number preferred_foot  \
# 12          1343.0             LCB                   3.0           Left
# 38          1335.0             CAM                  19.0          Right
# 51          1343.0              GK                   1.0          Right
# 58             NaN             NaN                   NaN          Right
# 62          1369.0             SUB                   9.0          Right
#
#     weak_foot  skill_moves  international_reputation      work_rate  \
# 12          2            2                         4       Low/High
# 38          4            4                         4    High/Medium
# 51          2            1                         4  Medium/Medium
# 58          3            2                         3       Low/High
# 62          4            3                         3    High/Medium
#
#            body_type real_face  release_clause_eur  \
# 12     Normal (185+)       Yes                 NaN
# 38       Lean (185+)       Yes                 NaN
# 51     Normal (185+)       Yes                 NaN
# 58     Normal (185+)       Yes                 NaN
# 62  Normal (170-185)       Yes                 NaN
#
#                      player_tags  \
# 12        #Tackling, #Tactician
# 38  #Distance Shooter, #Strength
# 51                           NaN
# 58        #Tackling, #Tactician
# 62                           NaN
#
#                                         player_traits  pace  shooting  \
# 12  Long Throw-in, Avoids Using Weaker Foot, Dives...  77.0      47.0
# 38  Dives Into Tackles (AI), Flair, Long Shot Take...  77.0      80.0
# 51           Leadership, One Club Player, Team Player   NaN       NaN
# 58                           Injury Prone, Leadership  75.0      36.0
# 62                                  Outside Foot Shot  80.0      85.0
#
#     passing  dribbling  defending  physic  attacking_crossing  \
# 12     56.0       58.0       90.0    84.0                  62
# 38     82.0       86.0       74.0    88.0                  76
# 51      NaN        NaN        NaN     NaN                  13
# 58     55.0       59.0       88.0    77.0                  40
# 62     68.0       81.0       22.0    71.0                  72
#
#     attacking_finishing  attacking_heading_accuracy  attacking_short_passing  \
# 12                   34                          84                       57
# 38                   70                          72                       85
# 51                   15                          13                       37
# 58                   26                          76                       65
# 62                   89                          77                       70
#
#     attacking_volleys  skill_dribbling  skill_curve  skill_fk_accuracy  \
# 12                 45               56           60                 31
# 38                 84               88           82                 80
# 51                 17               25           20                 13
# 58                 35               52           50                 31
# 62                 83               82           72                 62
#
#     skill_long_passing  skill_ball_control  movement_acceleration  \
# 12                  65                  53                     75
# 38                  81                  89                     75
# 51                  35                  23                     49
# 58                  65                  65                     73
# 62                  55                  84                     79
#
#     movement_sprint_speed  movement_agility  movement_reactions  \
# 12                     79                65                  80
# 38                     79                75                  86
# 51                     43                55                  76
# 58                     77                61                  80
# 62                     81                72                  83
#
#     movement_balance  power_shot_power  power_jumping  power_stamina  \
# 12                69                79             89             69
# 38                61                91             85             87
# 51                49                20             75             39
# 58                69                51             83             65
# 62                60                84             73             69
#
#     power_strength  power_long_shots  mentality_aggression  \
# 12              89                49                    88
# 38              91                91                    80
# 51              63                13                    38
# 58              83                39                    76
# 62              80                77                    50
#
#     mentality_interceptions  mentality_positioning  mentality_vision  \
# 12                       87                     33                46
# 38                       71                     83                86
# 51                       20                     14                50
# 58                       89                     33                50
# 62                       19                     88                70
#
#     mentality_penalties  mentality_composure  defending_marking_awareness  \
# 12                   50                  NaN                           91
# 38                   76                  NaN                           71
# 51                   22                  NaN                           10
# 58                   50                  NaN                           89
# 62                   74                  NaN                           15
#
#     defending_standing_tackle  defending_sliding_tackle  goalkeeping_diving  \
# 12                         91                        91                   3
# 38                         77                        83                   5
# 51                         11                        11                  85
# 58                         89                        89                   4
# 62                         15                        10                   5
#
#     goalkeeping_handling  goalkeeping_kicking  goalkeeping_positioning  \
# 12                     3                    2                        4
# 38                     6                    2                        4
# 51                    79                   71                       89
# 58                     2                    4                        2
# 62                    12                    7                        5
#
#     goalkeeping_reflexes  goalkeeping_speed    ls    st    rs    lw    lf  \
# 12                     3                NaN  59+2  59+2  59+2  56+2  55+2
# 38                     3                NaN  82+2  82+2  82+2  83+2  84+2
# 51                    83               46.0  28+2  28+2  28+2  31+2  31+2
# 58                     4                NaN  54+1  54+1  54+1  54+1  54+1
# 62                    10                NaN  83+1  83+1  83+1  80+1  82+1
#
#       cf    rf    rw   lam   cam   ram    lm   lcm    cm   rcm    rm   lwb  \
# 12  55+2  55+2  56+2  54+2  54+2  54+2  58+2  60+2  60+2  60+2  58+2  75+2
# 38  84+2  84+2  83+2  84+2  84+2  84+2  83+2  84+2  84+2  84+2  83+2  80+2
# 51  31+2  31+2  31+2  34+2  34+2  34+2  33+2  34+2  34+2  34+2  33+2  28+2
# 58  54+1  54+1  54+1  56+1  56+1  56+1  57+1  62+1  62+1  62+1  57+1  73+1
# 62  82+1  82+1  80+1  78+1  78+1  78+1  78+1  68+1  68+1  68+1  78+1  53+1
#
#      ldm   cdm   rdm   rwb    lb   lcb    cb   rcb    rb    gk  \
# 12  75+2  75+2  75+2  75+2  78+2  85+2  85+2  85+2  78+2  12+2
# 38  81+2  81+2  81+2  80+2  79+2  79+2  79+2  79+2  79+2  13+2
# 51  31+2  31+2  31+2  28+2  27+2  27+2  27+2  27+2  27+2  82+2
# 58  76+1  76+1  76+1  73+1  76+1  83+1  83+1  83+1  76+1  12+1
# 62  48+1  48+1  48+1  53+1  49+1  42+1  42+1  42+1  49+1  16+1
#
#                                       player_face_url  \
# 12  https://cdn.sofifa.net/players/138/956/16_120.png
# 38  https://cdn.sofifa.net/players/195/864/16_120.png
# 51  https://cdn.sofifa.net/players/001/179/16_120.png
# 58  https://cdn.sofifa.net/players/137/186/16_120.png
# 62  https://cdn.sofifa.net/players/167/664/16_120.png
#
#                              club_logo_url  \
# 12  https://cdn.sofifa.net/teams/45/60.png
# 38  https://cdn.sofifa.net/teams/45/60.png
# 51  https://cdn.sofifa.net/teams/45/60.png
# 58  https://cdn.sofifa.net/teams/45/60.png
# 62  https://cdn.sofifa.net/teams/48/60.png
#
#                           club_flag_url  \
# 12  https://cdn.sofifa.net/flags/it.png
# 38  https://cdn.sofifa.net/flags/it.png
# 51  https://cdn.sofifa.net/flags/it.png
# 58  https://cdn.sofifa.net/flags/it.png
# 62  https://cdn.sofifa.net/flags/it.png
#
#                              nation_logo_url  \
# 12  https://cdn.sofifa.net/teams/1343/60.png
# 38  https://cdn.sofifa.net/teams/1335/60.png
# 51  https://cdn.sofifa.net/teams/1343/60.png
# 58                                       NaN
# 62  https://cdn.sofifa.net/teams/1369/60.png
#
#                         nation_flag_url club_name_original
# 12  https://cdn.sofifa.net/flags/it.png           Juventus
# 38  https://cdn.sofifa.net/flags/fr.png           Juventus
# 51  https://cdn.sofifa.net/flags/it.png           Juventus
# 58  https://cdn.sofifa.net/flags/it.png           Juventus
# 62  https://cdn.sofifa.net/flags/ar.png             Napoli

# %%
valores_unicos_columna(df_jugadores_fifa_seriea, 'club_name')
# Out:
# array(['Juventus', 'Napoli', 'Inter Milan', 'AS Roma', 'Lazio',
#        'AC Milan', 'Fiorentina', 'Torino', 'Sampdoria', 'Genoa',
#        'Sassuolo', 'Udinese', 'Atalanta', 'Palermo', 'Bologna', 'Chievo',
#        'Hellas Verona', 'Empoli', 'Carpi', 'Frosinone'], dtype=object)

# %%
import pandas as pd
from rapidfuzz import process, fuzz

# 1. Cargar datasets ya cargados:
# df_jugadores
# df_jugadores_fifa_laliga

# 2. Fuzzy matching entre nombres de jugadores
def hacer_matching_aproximado(base_df, columna_base, df_referencia, columna_referencia, umbral=85):
    nombres_base = base_df[columna_base].unique()
    nombres_ref = df_referencia[columna_referencia].tolist()

    resultados = []

    for nombre in nombres_base:
        resultado = process.extractOne(nombre, nombres_ref, scorer=fuzz.token_sort_ratio)
        if resultado:
            mejor_match, score, _ = resultado
            revisar = score < umbral
        else:
            mejor_match, score, revisar = None, 0, True

        resultados.append({
            columna_base: nombre,
            f"{columna_referencia}_match": mejor_match,
            "score": score,
            "revisar": revisar
        })

    return pd.DataFrame(resultados)

# 3. Aplicar fuzzy matching jugador ↔ nombre FIFA
df_matching = hacer_matching_aproximado(
    base_df=df_jugadores,
    columna_base='player',
    df_referencia=df_jugadores_fifa_seriea,
    columna_referencia='long_name',
    umbral=85
)

# 4. Merge para traer el match
jugadores_matcheados = df_jugadores.merge(df_matching, on='player')

# 5. Merge con FIFA para traer info de jugador
jugadores_completo = jugadores_matcheados.merge(
    df_jugadores_fifa_seriea,
    left_on='long_name_match',
    right_on='long_name',
    how='left',
    suffixes=('', '_fifa')
)

# 6. Filtrar para que club_name (de FIFA) coincida con ultimo_equipo (StatsBomb)
jugadores_completo = jugadores_completo[jugadores_completo['ultimo_equipo'] == jugadores_completo['club_name']]

# 7. Guardar resultado final
jugadores_completo.to_csv("jugadores_con_datos_fifa_seriea.csv", index=False)
print("✅ Archivo guardado como 'jugadores_con_datos_fifa_laliga.csv'")

# 8. Mostrar jugadores que no se emparejaron bien
no_encontrados = jugadores_matcheados[~jugadores_matcheados['player'].isin(jugadores_completo['player'])]
print("\n❗ Jugadores que no se emparejaron con el mismo equipo:")
print(no_encontrados[['player', 'long_name_match', 'score', 'revisar']])
# Out:
# ✅ Archivo guardado como 'jugadores_con_datos_fifa_laliga.csv'
#
# ❗ Jugadores que no se emparejaron con el mismo equipo:
#                               player                  long_name_match  \
# 1                      Milan Biševac                     Milan Badelj
# 6                 Nathaniel Chalobah                   Daniel Ciofani
# 9    Gabriel Moisés Antunes da Silva  Gabriel Moisés Antunes da Silva
# 14                       Serge Gakpé                      Serge Gakpé
# 23       Emerson Palmieri dos Santos   Maurício dos Santos Nascimento
# ..                               ...                              ...
# 536                Cristian Zaccardo                Cristian Molinaro
# 546                  Filippo Porcari                 Filippo Lombardi
# 548                 Lorenzo Di Livio                    Lorenzo Lollo
# 549                     Vasyl Pryyma                     Valter Birsa
# 550                   Kévin Constant             Konstantinos Manolas
#
#           score  revisar
# 1     64.000000     True
# 6     56.250000     True
# 9    100.000000    False
# 14   100.000000    False
# 23    59.649123     True
# ..          ...      ...
# 536   70.588235     True
# 546   77.419355     True
# 548   68.965517     True
# 549   50.000000     True
# 550   52.941176     True
#
# [106 rows x 4 columns]

# %%
# 6. Guardar resultado
jugadores_completo.to_csv("datos/seriea_16_jugadores_fifa.csv", index=False)

# %%
columnas_deseadas = [
    'player_id', 'player', 'ultimo_equipo', 'ultimo_team_id', 'posiciones', 'partidos_jugados',
    'overall', 'potential', 'value_eur', 'wage_eur', 'age', 'dob', 'height_cm', 'weight_kg',
    'club_jersey_number', 'club_loaned_from', 'club_contract_valid_until',
    'nationality_id', 'nationality_name', 'preferred_foot', 'release_clause_eur'
]

# Filtrar el DataFrame
jugadores_completo_filtrado = jugadores_completo[columnas_deseadas]

# Guardar si lo deseas
jugadores_completo_filtrado.to_csv("datos/jugadores_seriea.csv", index=False)
print("✅ Archivo guardado como 'jugadores_filtrados_fifa_seriea.csv'")
# Out:
# ✅ Archivo guardado como 'jugadores_filtrados_fifa_seriea.csv'
