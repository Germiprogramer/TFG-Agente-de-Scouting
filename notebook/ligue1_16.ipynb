# %%
# !pip install statsbombpy
# !pip install mplsoccer
# !pip install highlight_text
# !pip install fuzzywuzzy[speedup]
# !pip install rapidfuzz pandas
# Out:
# Requirement already satisfied: statsbombpy in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (1.14.0)
# Requirement already satisfied: pandas in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from statsbombpy) (2.2.0)
# Requirement already satisfied: requests in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from statsbombpy) (2.31.0)
# Requirement already satisfied: requests-cache in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from statsbombpy) (1.2.1)
# Requirement already satisfied: inflect in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from statsbombpy) (7.4.0)
# Requirement already satisfied: joblib in c:\users\germán llorente\appdata\roaming\python\python39\site-packages (from statsbombpy) (1.2.0)
# Requirement already satisfied: more-itertools>=8.5.0 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from inflect->statsbombpy) (10.5.0)
# Requirement already satisfied: typeguard>=4.0.1 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from inflect->statsbombpy) (4.4.1)
# Requirement already satisfied: numpy<2,>=1.22.4 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from pandas->statsbombpy) (1.23.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from pandas->statsbombpy) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from pandas->statsbombpy) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from pandas->statsbombpy) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from requests->statsbombpy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from requests->statsbombpy) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from requests->statsbombpy) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from requests->statsbombpy) (2023.11.17)
# Requirement already satisfied: attrs>=21.2 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from requests-cache->statsbombpy) (23.1.0)
# Requirement already satisfied: cattrs>=22.2 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from requests-cache->statsbombpy) (24.1.2)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from requests-cache->statsbombpy) (4.0.0)
# Requirement already satisfied: url-normalize>=1.4 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from requests-cache->statsbombpy) (1.4.3)
# Requirement already satisfied: exceptiongroup>=1.1.1 in c:\users\germán llorente\appdata\roaming\python\python39\site-packages (from cattrs>=22.2->requests-cache->statsbombpy) (1.2.0)
# Requirement already satisfied: typing-extensions!=4.6.3,>=4.1.0 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from cattrs>=22.2->requests-cache->statsbombpy) (4.12.2)
# Requirement already satisfied: six>=1.5 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from python-dateutil>=2.8.2->pandas->statsbombpy) (1.16.0)
# Requirement already satisfied: importlib-metadata>=3.6 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from typeguard>=4.0.1->inflect->statsbombpy) (7.0.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from importlib-metadata>=3.6->typeguard>=4.0.1->inflect->statsbombpy) (3.17.0)
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: mplsoccer in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (1.4.0)
# Requirement already satisfied: matplotlib>=3.6 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from mplsoccer) (3.8.2)
# Requirement already satisfied: numpy in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from mplsoccer) (1.23.2)
# Requirement already satisfied: pandas in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from mplsoccer) (2.2.0)
# Requirement already satisfied: pillow in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from mplsoccer) (10.1.0)
# Requirement already satisfied: requests in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from mplsoccer) (2.31.0)
# Requirement already satisfied: scipy in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from mplsoccer) (1.11.4)
# Requirement already satisfied: seaborn in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from mplsoccer) (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.6->mplsoccer) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.6->mplsoccer) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.6->mplsoccer) (4.46.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.6->mplsoccer) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.6->mplsoccer) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.6->mplsoccer) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.6->mplsoccer) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.6->mplsoccer) (6.1.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from pandas->mplsoccer) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from pandas->mplsoccer) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from requests->mplsoccer) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from requests->mplsoccer) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from requests->mplsoccer) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from requests->mplsoccer) (2023.11.17)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from importlib-resources>=3.2.0->matplotlib>=3.6->mplsoccer) (3.17.0)
# Requirement already satisfied: six>=1.5 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.6->mplsoccer) (1.16.0)
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: highlight_text in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (0.2)
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: fuzzywuzzy[speedup] in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (0.18.0)
# Requirement already satisfied: python-levenshtein>=0.12 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from fuzzywuzzy[speedup]) (0.27.1)
# Requirement already satisfied: Levenshtein==0.27.1 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from python-levenshtein>=0.12->fuzzywuzzy[speedup]) (0.27.1)
# Requirement already satisfied: rapidfuzz<4.0.0,>=3.9.0 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from Levenshtein==0.27.1->python-levenshtein>=0.12->fuzzywuzzy[speedup]) (3.12.2)
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: rapidfuzz in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (3.12.2)
# Requirement already satisfied: pandas in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (2.2.0)
# Requirement already satisfied: numpy<2,>=1.22.4 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from pandas) (1.23.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ^C
# Requirement already satisfied: mplsoccer in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (1.4.0)
# Requirement already satisfied: matplotlib>=3.6 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from mplsoccer) (3.8.2)
# Requirement already satisfied: numpy in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from mplsoccer) (1.23.2)
# Requirement already satisfied: pandas in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from mplsoccer) (2.2.0)
# Requirement already satisfied: pillow in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from mplsoccer) (10.1.0)
# Requirement already satisfied: requests in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from mplsoccer) (2.31.0)
# Requirement already satisfied: scipy in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from mplsoccer) (1.11.4)
# Requirement already satisfied: seaborn in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from mplsoccer) (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.6->mplsoccer) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.6->mplsoccer) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.6->mplsoccer) (4.46.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.6->mplsoccer) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.6->mplsoccer) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.6->mplsoccer) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.6->mplsoccer) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from matplotlib>=3.6->mplsoccer) (6.1.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from pandas->mplsoccer) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from pandas->mplsoccer) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from requests->mplsoccer) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from requests->mplsoccer) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from requests->mplsoccer) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from requests->mplsoccer) (2023.11.17)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from importlib-resources>=3.2.0->matplotlib>=3.6->mplsoccer) (3.17.0)
# Requirement already satisfied: six>=1.5 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.6->mplsoccer) (1.16.0)
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: highlight_text in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (0.2)
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: fuzzywuzzy[speedup] in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (0.18.0)
# Requirement already satisfied: python-levenshtein>=0.12 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from fuzzywuzzy[speedup]) (0.27.1)
# Requirement already satisfied: Levenshtein==0.27.1 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from python-levenshtein>=0.12->fuzzywuzzy[speedup]) (0.27.1)
# Requirement already satisfied: rapidfuzz<4.0.0,>=3.9.0 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from Levenshtein==0.27.1->python-levenshtein>=0.12->fuzzywuzzy[speedup]) (3.12.2)
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: rapidfuzz in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (3.12.2)
# Requirement already satisfied: pandas in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (2.2.0)
# Requirement already satisfied: numpy<2,>=1.22.4 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from pandas) (1.23.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from funciones_analisis import *
from statsbombpy import sb
import pandas as pd
from mplsoccer import VerticalPitch, Pitch
from highlight_text import ax_text, fig_text
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap
import matplotlib.patheffects as path_effects
import seaborn as sns
from rapidfuzz import process, fuzz

# %%
free_comps = sb.competitions()

free_comps
# Out:
#     competition_id  season_id   country_name        competition_name  \
# 0                9        281        Germany           1. Bundesliga
# 1                9         27        Germany           1. Bundesliga
# 2             1267        107         Africa  African Cup of Nations
# 3               16          4         Europe        Champions League
# 4               16          1         Europe        Champions League
# ..             ...        ...            ...                     ...
# 69              55         43         Europe               UEFA Euro
# 70              35         75         Europe      UEFA Europa League
# 71              53        106         Europe       UEFA Women's Euro
# 72              72        107  International       Women's World Cup
# 73              72         30  International       Women's World Cup
#
#    competition_gender  competition_youth  competition_international  \
# 0                male              False                      False
# 1                male              False                      False
# 2                male              False                       True
# 3                male              False                      False
# 4                male              False                      False
# ..                ...                ...                        ...
# 69               male              False                       True
# 70               male              False                      False
# 71             female              False                       True
# 72             female              False                       True
# 73             female              False                       True
#
#    season_name               match_updated           match_updated_360  \
# 0    2023/2024  2024-07-15T14:15:54.671676  2024-07-15T14:17:00.877356
# 1    2015/2016  2024-05-19T11:11:14.192381                        None
# 2         2023  2024-06-13T07:51:02.452825                        None
# 3    2018/2019  2024-06-12T07:44:38.559714     2021-06-13T16:17:31.694
# 4    2017/2018  2024-02-13T02:35:28.134882     2021-06-13T16:17:31.694
# ..         ...                         ...                         ...
# 69        2020  2024-04-16T12:44:40.558402  2024-04-16T12:47:18.505110
# 70   1988/1989  2024-02-12T14:45:05.702250     2021-06-13T16:17:31.694
# 71        2022  2024-02-13T13:27:17.178263  2024-02-13T13:30:52.820588
# 72        2023  2024-07-14T16:59:48.469596  2024-07-14T17:01:38.887279
# 73        2019  2024-02-13T09:41:26.379767     2021-06-13T16:17:31.694
#
#            match_available_360             match_available
# 0   2024-07-15T14:17:00.877356  2024-07-15T14:15:54.671676
# 1                         None  2024-05-19T11:11:14.192381
# 2                         None  2024-06-13T07:51:02.452825
# 3                         None  2024-06-12T07:44:38.559714
# 4                         None  2024-02-13T02:35:28.134882
# ..                         ...                         ...
# 69  2024-04-16T12:47:18.505110  2024-04-16T12:44:40.558402
# 70                        None  2024-02-12T14:45:05.702250
# 71  2024-02-13T13:30:52.820588  2024-02-13T13:27:17.178263
# 72  2024-07-14T17:01:38.887279  2024-07-14T16:59:48.469596
# 73                        None  2024-02-13T09:41:26.379767
#
# [74 rows x 12 columns]

# %%
ligue1_16 = sb.matches(competition_id=7, season_id=27)

# %%
ligue1_16 = ordenar_partidos_cronologicamente(ligue1_16)

ligue1_16
# Out:
#      match_id  match_date      kick_off       competition     season  \
# 0     3829413  2015-08-07  20:30:00.000  France - Ligue 1  2015/2016
# 1     3829414  2015-08-08  21:00:00.000  France - Ligue 1  2015/2016
# 2     3829417  2015-08-08  21:00:00.000  France - Ligue 1  2015/2016
# 3     3829418  2015-08-08  21:00:00.000  France - Ligue 1  2015/2016
# 4     3829416  2015-08-08  21:00:00.000  France - Ligue 1  2015/2016
# ..        ...         ...           ...               ...        ...
# 372   3901256  2016-05-14  21:00:00.000  France - Ligue 1  2015/2016
# 373   3901257  2016-05-14  21:00:00.000  France - Ligue 1  2015/2016
# 374   3901258  2016-05-14  21:00:00.000  France - Ligue 1  2015/2016
# 375   3901261  2016-05-14  21:00:00.000  France - Ligue 1  2015/2016
# 376   3901254  2016-05-14  21:00:00.000  France - Ligue 1  2015/2016
#
#                home_team            away_team  home_score  away_score  \
# 0                  Lille  Paris Saint-Germain           0           1
# 1              Marseille                 Caen           0           1
# 2                 Troyes      Gazélec Ajaccio           0           0
# 3                 Nantes             Guingamp           1           0
# 4               OGC Nice            AS Monaco           1           2
# ..                   ...                  ...         ...         ...
# 372            AS Monaco          Montpellier           2           0
# 373        Saint-Étienne                Lille           0           1
# 374             Guingamp             OGC Nice           2           3
# 375  Paris Saint-Germain               Nantes           4           0
# 376       Stade de Reims                 Lyon           4           1
#
#     match_status  ... match_week competition_stage  \
# 0      available  ...          1    Regular Season
# 1      available  ...          1    Regular Season
# 2      available  ...          1    Regular Season
# 3      available  ...          1    Regular Season
# 4      available  ...          1    Regular Season
# ..           ...  ...        ...               ...
# 372    available  ...         38    Regular Season
# 373    available  ...         38    Regular Season
# 374    available  ...         38    Regular Season
# 375    available  ...         38    Regular Season
# 376    available  ...         38    Regular Season
#
#                                      stadium             referee  \
# 0      Decathlon Arena – Stade Pierre-Mauroy       Fredy Fautrel
# 1                           Orange Vélodrome     Frank Schneider
# 2                           Stade de l''Aube  Jérôme Miguelgorry
# 3    Stade de la Beaujoire - Louis Fonteneau      Benoît Bastien
# 4                           Allianz Riviera      Lionel Jaffredo
# ..                                       ...                 ...
# 372                           Stade Louis II      Benoît Bastien
# 373                 Stade Geoffroy-Guichard       Clément Turpin
# 374                       Stade du Roudourou        Ruddy Buquet
# 375                        Parc des Princes      Lionel Jaffredo
# 376                Stade Auguste-Delaune II       Amaury Delerue
#
#                               home_managers  \
# 0                              Hervé Renard
# 1            Marcelo Alberto Bielsa Caldera
# 2                          Jean-Marc Furlan
# 3                       Michel Der Zakarian
# 4                               Claude Puel
# ..                                      ...
# 372  José Leonardo Nunes Alves Sousa Jardim
# 373                      Christophe Galtier
# 374                      Jocelyn Gourvennec
# 375                           Laurent Blanc
# 376                             David Guion
#
#                               away_managers data_version  \
# 0                             Laurent Blanc        1.1.0
# 1                           Patrice Garande        1.1.0
# 2                            Thierry Laurey        1.1.0
# 3                        Jocelyn Gourvennec        1.1.0
# 4    José Leonardo Nunes Alves Sousa Jardim        1.1.0
# ..                                      ...          ...
# 372                          Frédéric Hantz        1.1.0
# 373                      Frédéric Antonetti        1.1.0
# 374                             Claude Puel        1.1.0
# 375                     Michel Der Zakarian        1.1.0
# 376                           Bruno Génésio        1.1.0
#
#     shot_fidelity_version xy_fidelity_version          fecha_hora
# 0                       2                   2 2015-08-07 20:30:00
# 1                       2                   2 2015-08-08 21:00:00
# 2                       2                   2 2015-08-08 21:00:00
# 3                       2                   2 2015-08-08 21:00:00
# 4                       2                   2 2015-08-08 21:00:00
# ..                    ...                 ...                 ...
# 372                     2                   2 2016-05-14 21:00:00
# 373                     2                   2 2016-05-14 21:00:00
# 374                     2                   2 2016-05-14 21:00:00
# 375                     2                   2 2016-05-14 21:00:00
# 376                     2                   2 2016-05-14 21:00:00
#
# [377 rows x 23 columns]

# %%
# Lista para guardar DataFrames de eventos
eventos_lista = []

# Descargar eventos de cada partido
for match_id in ligue1_16['match_id']:

        eventos = sb.events(match_id=match_id)
        eventos['match_id'] = match_id  # Añadir identificador de partido
        eventos_lista.append(eventos)


# Unir todos los DataFrames en uno solo
eventos_ligue1_16 = pd.concat(eventos_lista, ignore_index=True)

# Guardar como archivo CSV
#df_eventos.to_csv('eventos_seriea_2016.csv', index=False)

# %%
# Asegúrate de ejecutar esto antes de inspeccionar columnas
pd.set_option('display.max_columns', None)

# %%
# Convierte a lista y muestra tú mismo

# Mostrar columnas en orden alfabético, una por línea
for col in sorted(eventos_ligue1_16.columns):
    print(col)
# Out:
# 50_50
# bad_behaviour_card
# ball_receipt_outcome
# ball_recovery_offensive
# ball_recovery_recovery_failure
# block_deflection
# block_offensive
# block_save_block
# carry_end_location
# clearance_aerial_won
# clearance_body_part
# clearance_head
# clearance_left_foot
# clearance_other
# clearance_right_foot
# counterpress
# dribble_no_touch
# dribble_nutmeg
# dribble_outcome
# dribble_overrun
# duel_outcome
# duel_type
# duration
# foul_committed_advantage
# foul_committed_card
# foul_committed_offensive
# foul_committed_penalty
# foul_committed_type
# foul_won_advantage
# foul_won_defensive
# foul_won_penalty
# goalkeeper_body_part
# goalkeeper_end_location
# goalkeeper_lost_in_play
# goalkeeper_lost_out
# goalkeeper_outcome
# goalkeeper_penalty_saved_to_post
# goalkeeper_position
# goalkeeper_punched_out
# goalkeeper_shot_saved_off_target
# goalkeeper_shot_saved_to_post
# goalkeeper_success_in_play
# goalkeeper_success_out
# goalkeeper_technique
# goalkeeper_type
# half_start_late_video_start
# id
# index
# injury_stoppage_in_chain
# interception_outcome
# location
# match_id
# minute
# miscontrol_aerial_won
# off_camera
# out
# pass_aerial_won
# pass_angle
# pass_assisted_shot_id
# pass_body_part
# pass_cross
# pass_cut_back
# pass_deflected
# pass_end_location
# pass_goal_assist
# pass_height
# pass_inswinging
# pass_length
# pass_miscommunication
# pass_no_touch
# pass_outcome
# pass_outswinging
# pass_recipient
# pass_recipient_id
# pass_shot_assist
# pass_straight
# pass_switch
# pass_technique
# pass_through_ball
# pass_type
# period
# play_pattern
# player
# player_id
# player_off_permanent
# position
# possession
# possession_team
# possession_team_id
# related_events
# second
# shot_aerial_won
# shot_body_part
# shot_deflected
# shot_end_location
# shot_first_time
# shot_follows_dribble
# shot_freeze_frame
# shot_key_pass_id
# shot_one_on_one
# shot_open_goal
# shot_outcome
# shot_redirect
# shot_saved_off_target
# shot_saved_to_post
# shot_statsbomb_xg
# shot_technique
# shot_type
# substitution_outcome
# substitution_outcome_id
# substitution_replacement
# substitution_replacement_id
# tactics
# team
# team_id
# timestamp
# type
# under_pressure

# %%
eventos_ligue1_16.head()
# Out:
#   ball_receipt_outcome ball_recovery_offensive ball_recovery_recovery_failure  \
# 0                  NaN                     NaN                            NaN
# 1                  NaN                     NaN                            NaN
# 2                  NaN                     NaN                            NaN
# 3                  NaN                     NaN                            NaN
# 4                  NaN                     NaN                            NaN
#
#   block_deflection block_offensive carry_end_location clearance_aerial_won  \
# 0              NaN             NaN                NaN                  NaN
# 1              NaN             NaN                NaN                  NaN
# 2              NaN             NaN                NaN                  NaN
# 3              NaN             NaN                NaN                  NaN
# 4              NaN             NaN                NaN                  NaN
#
#   clearance_body_part clearance_head clearance_left_foot clearance_right_foot  \
# 0                 NaN            NaN                 NaN                  NaN
# 1                 NaN            NaN                 NaN                  NaN
# 2                 NaN            NaN                 NaN                  NaN
# 3                 NaN            NaN                 NaN                  NaN
# 4                 NaN            NaN                 NaN                  NaN
#
#   counterpress dribble_no_touch dribble_nutmeg dribble_outcome  \
# 0          NaN              NaN            NaN             NaN
# 1          NaN              NaN            NaN             NaN
# 2          NaN              NaN            NaN             NaN
# 3          NaN              NaN            NaN             NaN
# 4          NaN              NaN            NaN             NaN
#
#   dribble_overrun duel_outcome duel_type  duration foul_committed_advantage  \
# 0             NaN          NaN       NaN       0.0                      NaN
# 1             NaN          NaN       NaN       0.0                      NaN
# 2             NaN          NaN       NaN       0.0                      NaN
# 3             NaN          NaN       NaN       0.0                      NaN
# 4             NaN          NaN       NaN       0.0                      NaN
#
#   foul_committed_card foul_committed_type foul_won_advantage  \
# 0                 NaN                 NaN                NaN
# 1                 NaN                 NaN                NaN
# 2                 NaN                 NaN                NaN
# 3                 NaN                 NaN                NaN
# 4                 NaN                 NaN                NaN
#
#   foul_won_defensive goalkeeper_body_part goalkeeper_end_location  \
# 0                NaN                  NaN                     NaN
# 1                NaN                  NaN                     NaN
# 2                NaN                  NaN                     NaN
# 3                NaN                  NaN                     NaN
# 4                NaN                  NaN                     NaN
#
#   goalkeeper_lost_in_play goalkeeper_outcome goalkeeper_position  \
# 0                     NaN                NaN                 NaN
# 1                     NaN                NaN                 NaN
# 2                     NaN                NaN                 NaN
# 3                     NaN                NaN                 NaN
# 4                     NaN                NaN                 NaN
#
#   goalkeeper_technique goalkeeper_type                                    id  \
# 0                  NaN             NaN  8bb103d5-8b88-46ce-be2d-5f08153df01f
# 1                  NaN             NaN  bd94d578-e87e-476c-bbef-502df13a77ab
# 2                  NaN             NaN  d9aaae89-5a43-493c-b26d-5a1605ac2a02
# 3                  NaN             NaN  fca86857-f917-44d8-b3b7-fc1ce90512f1
# 4                  NaN             NaN  4b5274da-5a63-4263-9e66-d53fccbae94e
#
#    index interception_outcome location  match_id  minute off_camera  out  \
# 0      1                  NaN      NaN   3829413       0        NaN  NaN
# 1      2                  NaN      NaN   3829413       0        NaN  NaN
# 2      3                  NaN      NaN   3829413       0        NaN  NaN
# 3      4                  NaN      NaN   3829413       0        NaN  NaN
# 4   1638                  NaN      NaN   3829413      45        NaN  NaN
#
#   pass_aerial_won  pass_angle pass_assisted_shot_id pass_body_part pass_cross  \
# 0             NaN         NaN                   NaN            NaN        NaN
# 1             NaN         NaN                   NaN            NaN        NaN
# 2             NaN         NaN                   NaN            NaN        NaN
# 3             NaN         NaN                   NaN            NaN        NaN
# 4             NaN         NaN                   NaN            NaN        NaN
#
#   pass_cut_back pass_end_location pass_goal_assist pass_height  \
# 0           NaN               NaN              NaN         NaN
# 1           NaN               NaN              NaN         NaN
# 2           NaN               NaN              NaN         NaN
# 3           NaN               NaN              NaN         NaN
# 4           NaN               NaN              NaN         NaN
#
#   pass_inswinging  pass_length pass_no_touch pass_outcome pass_outswinging  \
# 0             NaN          NaN           NaN          NaN              NaN
# 1             NaN          NaN           NaN          NaN              NaN
# 2             NaN          NaN           NaN          NaN              NaN
# 3             NaN          NaN           NaN          NaN              NaN
# 4             NaN          NaN           NaN          NaN              NaN
#
#   pass_recipient  pass_recipient_id pass_shot_assist pass_switch  \
# 0            NaN                NaN              NaN         NaN
# 1            NaN                NaN              NaN         NaN
# 2            NaN                NaN              NaN         NaN
# 3            NaN                NaN              NaN         NaN
# 4            NaN                NaN              NaN         NaN
#
#   pass_technique pass_through_ball pass_type  period    play_pattern player  \
# 0            NaN               NaN       NaN       1    Regular Play    NaN
# 1            NaN               NaN       NaN       1    Regular Play    NaN
# 2            NaN               NaN       NaN       1    Regular Play    NaN
# 3            NaN               NaN       NaN       1    Regular Play    NaN
# 4            NaN               NaN       NaN       2  From Free Kick    NaN
#
#    player_id position  possession possession_team  possession_team_id  \
# 0        NaN      NaN           1           Lille                 143
# 1        NaN      NaN           1           Lille                 143
# 2        NaN      NaN           1           Lille                 143
# 3        NaN      NaN           1           Lille                 143
# 4        NaN      NaN          79           Lille                 143
#
#                            related_events  second shot_aerial_won  \
# 0                                     NaN       0             NaN
# 1                                     NaN       0             NaN
# 2  [fca86857-f917-44d8-b3b7-fc1ce90512f1]       0             NaN
# 3  [d9aaae89-5a43-493c-b26d-5a1605ac2a02]       0             NaN
# 4  [1571b013-dcdf-4ea4-8c73-9e0ced174b7c]       0             NaN
#
#   shot_body_part shot_end_location shot_first_time shot_freeze_frame  \
# 0            NaN               NaN             NaN               NaN
# 1            NaN               NaN             NaN               NaN
# 2            NaN               NaN             NaN               NaN
# 3            NaN               NaN             NaN               NaN
# 4            NaN               NaN             NaN               NaN
#
#   shot_key_pass_id shot_one_on_one shot_open_goal shot_outcome  \
# 0              NaN             NaN            NaN          NaN
# 1              NaN             NaN            NaN          NaN
# 2              NaN             NaN            NaN          NaN
# 3              NaN             NaN            NaN          NaN
# 4              NaN             NaN            NaN          NaN
#
#    shot_statsbomb_xg shot_technique shot_type substitution_outcome  \
# 0                NaN            NaN       NaN                  NaN
# 1                NaN            NaN       NaN                  NaN
# 2                NaN            NaN       NaN                  NaN
# 3                NaN            NaN       NaN                  NaN
# 4                NaN            NaN       NaN                  NaN
#
#    substitution_outcome_id substitution_replacement  \
# 0                      NaN                      NaN
# 1                      NaN                      NaN
# 2                      NaN                      NaN
# 3                      NaN                      NaN
# 4                      NaN                      NaN
#
#    substitution_replacement_id  \
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
#
#                                              tactics                 team  \
# 0  {'formation': 442, 'lineup': [{'player': {'id'...                Lille
# 1  {'formation': 433, 'lineup': [{'player': {'id'...  Paris Saint-Germain
# 2                                                NaN                Lille
# 3                                                NaN  Paris Saint-Germain
# 4                                                NaN                Lille
#
#    team_id     timestamp         type under_pressure 50_50 block_save_block  \
# 0      143  00:00:00.000  Starting XI            NaN   NaN              NaN
# 1      131  00:00:00.000  Starting XI            NaN   NaN              NaN
# 2      143  00:00:00.000   Half Start            NaN   NaN              NaN
# 3      131  00:00:00.000   Half Start            NaN   NaN              NaN
# 4      143  00:00:00.000   Half Start            NaN   NaN              NaN
#
#   foul_committed_offensive goalkeeper_shot_saved_to_post  \
# 0                      NaN                           NaN
# 1                      NaN                           NaN
# 2                      NaN                           NaN
# 3                      NaN                           NaN
# 4                      NaN                           NaN
#
#   injury_stoppage_in_chain miscontrol_aerial_won shot_saved_to_post  \
# 0                      NaN                   NaN                NaN
# 1                      NaN                   NaN                NaN
# 2                      NaN                   NaN                NaN
# 3                      NaN                   NaN                NaN
# 4                      NaN                   NaN                NaN
#
#   foul_committed_penalty foul_won_penalty goalkeeper_shot_saved_off_target  \
# 0                    NaN              NaN                              NaN
# 1                    NaN              NaN                              NaN
# 2                    NaN              NaN                              NaN
# 3                    NaN              NaN                              NaN
# 4                    NaN              NaN                              NaN
#
#   pass_deflected pass_straight shot_saved_off_target bad_behaviour_card  \
# 0            NaN           NaN                   NaN                NaN
# 1            NaN           NaN                   NaN                NaN
# 2            NaN           NaN                   NaN                NaN
# 3            NaN           NaN                   NaN                NaN
# 4            NaN           NaN                   NaN                NaN
#
#   pass_miscommunication shot_deflected shot_redirect clearance_other  \
# 0                   NaN            NaN           NaN             NaN
# 1                   NaN            NaN           NaN             NaN
# 2                   NaN            NaN           NaN             NaN
# 3                   NaN            NaN           NaN             NaN
# 4                   NaN            NaN           NaN             NaN
#
#   goalkeeper_punched_out half_start_late_video_start shot_follows_dribble  \
# 0                    NaN                         NaN                  NaN
# 1                    NaN                         NaN                  NaN
# 2                    NaN                         NaN                  NaN
# 3                    NaN                         NaN                  NaN
# 4                    NaN                         NaN                  NaN
#
#   goalkeeper_success_out player_off_permanent goalkeeper_success_in_play  \
# 0                    NaN                  NaN                        NaN
# 1                    NaN                  NaN                        NaN
# 2                    NaN                  NaN                        NaN
# 3                    NaN                  NaN                        NaN
# 4                    NaN                  NaN                        NaN
#
#   goalkeeper_lost_out goalkeeper_penalty_saved_to_post
# 0                 NaN                              NaN
# 1                 NaN                              NaN
# 2                 NaN                              NaN
# 3                 NaN                              NaN
# 4                 NaN                              NaN

# %%
def perfil_jugadores(df_eventos):
    # Eliminar eventos sin jugador
    df = df_eventos.dropna(subset=['player_id', 'player']).copy()

    # Lista para guardar los resultados
    perfiles = []

    # Agrupar por jugador
    for player_id, grupo in df.groupby('player_id'):
        nombre = grupo['player'].iloc[-1]
        ultimo_equipo = grupo['team'].dropna().iloc[-1] if 'team' in grupo else None
        ultimo_team_id = grupo['team_id'].dropna().iloc[-1] if 'team_id' in grupo else None
        posiciones = grupo['position'].dropna().unique().tolist()
        partidos_jugados = grupo['match_id'].nunique()  # contar partidos únicos

        perfiles.append({
            'player_id': int(player_id),
            'player': nombre,
            'ultimo_equipo': ultimo_equipo,
            'ultimo_team_id': ultimo_team_id,
            'posiciones': posiciones,
            'partidos_jugados': partidos_jugados
        })

    return pd.DataFrame(perfiles)


perfiles_jugadores = perfil_jugadores(eventos_ligue1_16)


#MemoryError: Unable to allocate 1.03 GiB for an array with shape (102, 1353102) and data type object
# Out:
#   Cell In[18], line 30
#     '''
#        ^
# SyntaxError: EOF while scanning triple-quoted string literal

# %%
perfiles_jugadores
# Out:
#      player_id                    player  ultimo_equipo  ultimo_team_id  \
# 0         2936        Christophe Kerbrat       Guingamp             142
# 1         2943               Lucas Deaux         Nantes             144
# 2         2944          Benjamin Corgnet  Saint-Étienne             135
# 3         2946         Frédéric Guilbert       Bordeaux             146
# 4         2947             Anthony Lopes           Lyon             137
# ..         ...                       ...            ...             ...
# 567     403310             Ilias Hassani       Bordeaux             146
# 568     403377  Stéphan Raheriharimanana       OGC Nice             136
# 569     403378            Antony Ranieri       OGC Nice             136
# 570     403390              Jean Ambrose       Bordeaux             146
# 571     403392               Diego Gómez         Angers             145
#
#                                             posiciones  partidos_jugados
# 0                                  [Right Center Back]                29
# 1    [Left Center Back, Right Defensive Midfield, C...                16
# 2    [Center Forward, Center Attacking Midfield, Ri...                16
# 3                      [Right Back, Right Center Back]                29
# 4                                         [Goalkeeper]                37
# ..                                                 ...               ...
# 567                                [Right Center Back]                 1
# 568  [Right Defensive Midfield, Right Center Midfie...                 4
# 569                             [Right Center Forward]                 2
# 570                                   [Center Forward]                 1
# 571                             [Left Center Midfield]                 1
#
# [572 rows x 6 columns]

# %%
perfiles_jugadores['player_id'] = perfiles_jugadores['player_id'].astype(int)
perfiles_jugadores
# Out:
#      player_id                    player  ultimo_equipo  ultimo_team_id  \
# 0         2936        Christophe Kerbrat       Guingamp             142
# 1         2943               Lucas Deaux         Nantes             144
# 2         2944          Benjamin Corgnet  Saint-Étienne             135
# 3         2946         Frédéric Guilbert       Bordeaux             146
# 4         2947             Anthony Lopes           Lyon             137
# ..         ...                       ...            ...             ...
# 567     403310             Ilias Hassani       Bordeaux             146
# 568     403377  Stéphan Raheriharimanana       OGC Nice             136
# 569     403378            Antony Ranieri       OGC Nice             136
# 570     403390              Jean Ambrose       Bordeaux             146
# 571     403392               Diego Gómez         Angers             145
#
#                                             posiciones  partidos_jugados
# 0                                  [Right Center Back]                29
# 1    [Left Center Back, Right Defensive Midfield, C...                16
# 2    [Center Forward, Center Attacking Midfield, Ri...                16
# 3                      [Right Back, Right Center Back]                29
# 4                                         [Goalkeeper]                37
# ..                                                 ...               ...
# 567                                [Right Center Back]                 1
# 568  [Right Defensive Midfield, Right Center Midfie...                 4
# 569                             [Right Center Forward]                 2
# 570                                   [Center Forward]                 1
# 571                             [Left Center Midfield]                 1
#
# [572 rows x 6 columns]

# %%
def obtener_datos_generales_equipos(df):
    """Extrae team y team_id únicos presentes en el DataFrame."""
    return df[['team_id', 'team']].drop_duplicates().reset_index(drop=True)

# %%
equipos_df = obtener_datos_generales_equipos(eventos_ligue1_16)
print(equipos_df)
# Out:
#     team_id                 team
# 0       143                Lille
# 1       131  Paris Saint-Germain
# 2       147            Marseille
# 3       140                 Caen
# 4       133               Troyes
# 5       160      Gazélec Ajaccio
# 6       144               Nantes
# 7       142             Guingamp
# 8       136             OGC Nice
# 9       129            AS Monaco
# 10      139          Montpellier
# 11      145               Angers
# 12     2736               Bastia
# 13      134               Rennes
# 14      146             Bordeaux
# 15      156       Stade de Reims
# 16      130             Toulouse
# 17      135        Saint-Étienne
# 18      137                 Lyon
# 19      165              Lorient

# %%
from rapidfuzz import process, fuzz
import pandas as pd

def hacer_matching_aproximado(base_df, columna_base, df_referencia, columna_referencia, umbral=85):
    """
    Realiza un emparejamiento difuso (fuzzy matching) entre dos listas de nombres.

    Parámetros:
    - base_df: DataFrame con los nombres originales (por ejemplo, nombres en statsbomb).
    - columna_base: columna en base_df con los nombres a emparejar (ej: 'team', 'player').
    - df_referencia: DataFrame con los nombres de referencia (por ejemplo, datos económicos).
    - columna_referencia: columna en df_referencia con los nombres correctos (ej: 'team').
    - umbral: valor mínimo de similitud para aceptar automáticamente (default = 85).

    Devuelve:
    - DataFrame con columnas: nombre original, nombre emparejado, score, revisar (True/False)
    """
    nombres_base = base_df[columna_base].unique()
    nombres_ref = df_referencia[columna_referencia].tolist()

    resultados = []

    for nombre in nombres_base:
        mejor_match, score, _ = process.extractOne(nombre, nombres_ref, scorer=fuzz.token_sort_ratio)
        revisar = score < umbral
        resultados.append({
            columna_base: nombre,
            f"{columna_referencia}_match": mejor_match,
            "score": score,
            "revisar": revisar
        })

    return pd.DataFrame(resultados)

# %%
# Ruta al archivo desde tu script
df_economicos = pd.read_csv("datos/fifa_economicos/datos_economicos_ligue1.csv")

# %%
# 1. Aplicar fuzzy matching
df_matching = hacer_matching_aproximado(
    base_df=equipos_df,
    columna_base='team',
    df_referencia=df_economicos,
    columna_referencia='team',
    umbral=85
)

# 2. Hacer el merge con los datos económicos
equipos_matcheados = equipos_df.merge(df_matching, on='team')
equipos_completos = equipos_matcheados.merge(
    df_economicos,
    left_on='team_match',
    right_on='team',
    how='left',
    suffixes=('', '_econ')
)

# %%
equipos_completos
# Out:
#     team_id                 team           team_match       score  revisar  \
# 0       143                Lille           LOSC Lille   66.666667     True
# 1       131  Paris Saint-Germain        Stade Rennais   43.750000     True
# 2       147            Marseille  Olympique Marseille   64.285714     True
# 3       140                 Caen              SM Caen   72.727273     True
# 4       133               Troyes         ESTAC Troyes   66.666667     True
# 5       160      Gazélec Ajaccio          GFC Ajaccio   69.230769     True
# 6       144               Nantes            FC Nantes   80.000000     True
# 7       142             Guingamp          EA Guingamp   84.210526     True
# 8       136             OGC Nice             OGC Nice  100.000000    False
# 9       129            AS Monaco            AS Monaco  100.000000    False
# 10      139          Montpellier      Montpellier HSC   84.615385     True
# 11      145               Angers           Angers SCO   75.000000     True
# 12     2736               Bastia            SC Bastia   80.000000     True
# 13      134               Rennes        Stade Rennais   52.631579     True
# 14      146             Bordeaux        Gir. Bordeaux   76.190476     True
# 15      156       Stade de Reims          Stade Reims   88.000000    False
# 16      130             Toulouse          Toulouse FC   84.210526     True
# 17      135        Saint-Étienne            FC Nantes   36.363636     True
# 18      137                 Lyon       Olympique Lyon   44.444444     True
# 19      165              Lorient           FC Lorient   82.352941     True
#
#               team_econ  presupuesto_fichajes  presupuesto_sueldos
# 0            LOSC Lille              10500000               806000
# 1         Stade Rennais               9000000               963250
# 2   Olympique Marseille              18000000              1311000
# 3               SM Caen               3500000               471250
# 4          ESTAC Troyes               2200000               390500
# 5           GFC Ajaccio               2000000               261250
# 6             FC Nantes               5000000               613750
# 7           EA Guingamp               3200000               597000
# 8              OGC Nice               4500000               607500
# 9             AS Monaco              55000000              1458000
# 10      Montpellier HSC               7500000               773500
# 11           Angers SCO               2400000               333500
# 12            SC Bastia               2800000               377500
# 13        Stade Rennais               9000000               963250
# 14        Gir. Bordeaux               7000000               882250
# 15          Stade Reims               3000000               579500
# 16          Toulouse FC               5500000               789250
# 17            FC Nantes               5000000               613750
# 18       Olympique Lyon              17000000              1733750
# 19           FC Lorient               3700000               586000

# %%
columnas_a_eliminar = ['team_match', 'score', 'revisar', 'team_econ']
laliga_limpio = equipos_completos.drop(columns=columnas_a_eliminar)

# %%
laliga_limpio.to_csv("datos/datos_equipos/ligue116_equipos.csv", index=False)

# %%
# 1. Cargar los datasets
df_jugadores = perfiles_jugadores     # StatsBomb
df_fifa = pd.read_csv("datos/fifa16.csv")     

# 2. Filtrar jugadores de LaLiga en FIFA
df_jugadores_fifa_ligue1 = df_fifa[df_fifa['league_name'] == "French Ligue 1"].copy()
# Out:
# C:\Users\Germán Llorente\AppData\Local\Temp\ipykernel_28660\778337100.py:3: DtypeWarning: Columns (104) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_fifa = pd.read_csv("datos/fifa16.csv")

# %%
df_jugadores_fifa_ligue1.head()
# Out:
#     sofifa_id                                         player_url  \
# 5       41236  https://sofifa.com/player/41236/zlatan-ibrahim...
# 8      164240  https://sofifa.com/player/164240/thiago-emilia...
# 47     179813  https://sofifa.com/player/179813/edinson-cavan...
# 49     183898  https://sofifa.com/player/183898/angel-di-mari...
# 65     170890  https://sofifa.com/player/170890/blaise-matuid...
#
#         short_name                        long_name player_positions  overall  \
# 5   Z. Ibrahimović               Zlatan Ibrahimović               ST       89
# 8     Thiago Silva         Thiago Emiliano da Silva               CB       88
# 47       E. Cavani     Edinson Roberto Cavani Gómez       ST, LW, RW       85
# 49     Á. Di María  Ángel Fabián Di María Hernández      CAM, CM, RM       85
# 65      B. Matuidi                   Blaise Matuidi          CDM, CM       84
#
#     potential   value_eur  wage_eur  age         dob  height_cm  weight_kg  \
# 5          89  40500000.0  220000.0   33  1981-10-03        195         95
# 8          88  38000000.0  200000.0   30  1984-09-22        183         79
# 47         85  33500000.0  200000.0   28  1987-02-14        184         71
# 49         85  34000000.0  200000.0   27  1988-02-14        180         75
# 65         85  25500000.0  180000.0   28  1987-04-09        175         70
#
#     club_team_id            club_name     league_name  league_level  \
# 5           73.0  Paris Saint-Germain  French Ligue 1           1.0
# 8           73.0  Paris Saint-Germain  French Ligue 1           1.0
# 47          73.0  Paris Saint-Germain  French Ligue 1           1.0
# 49          73.0  Paris Saint-Germain  French Ligue 1           1.0
# 65          73.0  Paris Saint-Germain  French Ligue 1           1.0
#
#    club_position  club_jersey_number club_loaned_from club_joined  \
# 5             ST                10.0              NaN  2012-07-01
# 8            RCB                 2.0              NaN  2012-07-01
# 47            RW                 9.0              NaN  2013-07-16
# 49            LW                11.0              NaN  2015-08-06
# 65           LCM                14.0              NaN  2011-07-01
#
#     club_contract_valid_until  nationality_id nationality_name  \
# 5                      2016.0              46           Sweden
# 8                      2018.0              54           Brazil
# 47                     2018.0              60          Uruguay
# 49                     2019.0              52        Argentina
# 65                     2018.0              18           France
#
#     nation_team_id nation_position  nation_jersey_number preferred_foot  \
# 5           1363.0              LS                  10.0          Right
# 8           1370.0             SUB                  14.0          Right
# 47          1377.0             SUB                  21.0          Right
# 49          1369.0              LW                   7.0           Left
# 65          1335.0             LCM                  14.0           Left
#
#     weak_foot  skill_moves  international_reputation    work_rate  \
# 5           4            4                         5   Medium/Low
# 8           3            3                         4    High/High
# 47          3            3                         4    High/High
# 49          2            4                         4  High/Medium
# 65          3            2                         3    High/High
#
#            body_type real_face  release_clause_eur  \
# 5      Normal (185+)       Yes                 NaN
# 8   Normal (170-185)       Yes                 NaN
# 47    Lean (170-185)       Yes                 NaN
# 49    Lean (170-185)       Yes                 NaN
# 65    Lean (170-185)       Yes                 NaN
#
#                                           player_tags  \
# 5   #Poacher, #Aerial Threat, #Distance Shooter, #...
# 8                              #Tackling, #Tactician
# 47                                            #Engine
# 49                      #Dribbler, #Crosser, #Acrobat
# 65                               #Engine, #Tactician
#
#                                         player_traits  pace  shooting  \
# 5   Power Free-Kick, Leadership, Flair, Long Shot ...  73.0      90.0
# 8          Leadership, Long Passer (AI), Power Header  74.0      57.0
# 47                    Beat Offside Trap, Power Header  76.0      83.0
# 49  Diver, Avoids Using Weaker Foot, Dives Into Ta...  88.0      79.0
# 65                           Injury Free, Team Player  75.0      67.0
#
#     passing  dribbling  defending  physic  attacking_crossing  \
# 5      81.0       85.0       31.0    86.0                  76
# 8      73.0       73.0       90.0    79.0                  60
# 47     71.0       81.0       42.0    80.0                  70
# 49     83.0       86.0       49.0    70.0                  90
# 65     77.0       75.0       83.0    81.0                  75
#
#     attacking_finishing  attacking_heading_accuracy  attacking_short_passing  \
# 5                    90                          76                       84
# 8                    38                          82                       79
# 47                   85                          86                       77
# 49                   75                          53                       81
# 65                   65                          73                       84
#
#     attacking_volleys  skill_dribbling  skill_curve  skill_fk_accuracy  \
# 5                  92               87           80                 80
# 8                  63               68           61                 73
# 47                 82               81           75                 77
# 49                 77               87           83                 72
# 65                 72               73           65                 52
#
#     skill_long_passing  skill_ball_control  movement_acceleration  \
# 5                   76                  90                     72
# 8                   81                  80                     72
# 47                  50                  83                     74
# 49                  81                  86                     88
# 65                  79                  77                     74
#
#     movement_sprint_speed  movement_agility  movement_reactions  \
# 5                      74                86                  85
# 8                      76                75                  84
# 47                     78                82                  85
# 49                     88                90                  80
# 65                     76                77                  83
#
#     movement_balance  power_shot_power  power_jumping  power_stamina  \
# 5                 41                93             72             75
# 8                 68                78             93             74
# 47                59                85             88             90
# 49                79                87             72             78
# 65                79                74             83             94
#
#     power_strength  power_long_shots  mentality_aggression  \
# 5               93                88                    84
# 8               81                71                    77
# 47              74                78                    82
# 49              64                79                    76
# 65              73                66                    84
#
#     mentality_interceptions  mentality_positioning  mentality_vision  \
# 5                        20                     86                83
# 8                        91                     59                74
# 47                       48                     85                77
# 49                       38                     84                83
# 65                       86                     70                74
#
#     mentality_penalties  mentality_composure  defending_marking_awareness  \
# 5                    91                  NaN                           15
# 8                    71                  NaN                           90
# 47                   82                  NaN                           24
# 49                   73                  NaN                           37
# 65                   56                  NaN                           82
#
#     defending_standing_tackle  defending_sliding_tackle  goalkeeping_diving  \
# 5                          41                        27                  13
# 8                          91                        89                   9
# 47                         45                        27                  12
# 49                         63                        61                  10
# 65                         84                        83                   8
#
#     goalkeeping_handling  goalkeeping_kicking  goalkeeping_positioning  \
# 5                     15                   10                        9
# 8                     12                    5                        9
# 47                     5                   13                       13
# 49                     7                   11                       12
# 65                    11                    5                       10
#
#     goalkeeping_reflexes  goalkeeping_speed    ls    st    rs    lw    lf  \
# 5                     12                NaN  86+3  86+3  86+3  84+3  86+3
# 8                     10                NaN  68+2  68+2  68+2  69+2  70+2
# 47                    10                NaN  83+2  83+2  83+2  80+2  82+2
# 49                    11                NaN  79+2  79+2  79+2  84+1  83+2
# 65                    14                NaN  73+1  73+1  73+1  75+1  74+1
#
#       cf    rf    rw   lam   cam   ram    lm   lcm    cm   rcm    rm   lwb  \
# 5   86+3  86+3  84+3  85+3  85+3  85+3  83+3  78+3  78+3  78+3  83+3  60+3
# 8   70+2  70+2  69+2  72+2  72+2  72+2  71+2  77+2  77+2  77+2  71+2  80+2
# 47  82+2  82+2  80+2  79+2  79+2  79+2  79+2  74+2  74+2  74+2  79+2  63+2
# 49  83+2  83+2  84+1  83+2  83+2  83+2  84+1  79+2  79+2  79+2  84+1  71+2
# 65  74+1  74+1  75+1  76+1  76+1  76+1  77+1  79+1  79+1  79+1  77+1  82+1
#
#      ldm   cdm   rdm   rwb    lb   lcb    cb   rcb    rb    gk  \
# 5   60+3  60+3  60+3  60+3  56+3  53+3  53+3  53+3  56+3  20+3
# 8   84+2  84+2  84+2  80+2  82+2  86+2  86+2  86+2  82+2  18+2
# 47  61+2  61+2  61+2  63+2  61+2  57+2  57+2  57+2  61+2  18+2
# 49  67+2  67+2  67+2  71+2  68+2  59+2  59+2  59+2  68+2  18+2
# 65  83+1  83+1  83+1  82+1  82+1  81+1  81+1  81+1  82+1  18+1
#
#                                       player_face_url  \
# 5   https://cdn.sofifa.net/players/041/236/16_120.png
# 8   https://cdn.sofifa.net/players/164/240/16_120.png
# 47  https://cdn.sofifa.net/players/179/813/16_120.png
# 49  https://cdn.sofifa.net/players/183/898/16_120.png
# 65  https://cdn.sofifa.net/players/170/890/16_120.png
#
#                              club_logo_url  \
# 5   https://cdn.sofifa.net/teams/73/60.png
# 8   https://cdn.sofifa.net/teams/73/60.png
# 47  https://cdn.sofifa.net/teams/73/60.png
# 49  https://cdn.sofifa.net/teams/73/60.png
# 65  https://cdn.sofifa.net/teams/73/60.png
#
#                           club_flag_url  \
# 5   https://cdn.sofifa.net/flags/fr.png
# 8   https://cdn.sofifa.net/flags/fr.png
# 47  https://cdn.sofifa.net/flags/fr.png
# 49  https://cdn.sofifa.net/flags/fr.png
# 65  https://cdn.sofifa.net/flags/fr.png
#
#                              nation_logo_url  \
# 5   https://cdn.sofifa.net/teams/1363/60.png
# 8   https://cdn.sofifa.net/teams/1370/60.png
# 47  https://cdn.sofifa.net/teams/1377/60.png
# 49  https://cdn.sofifa.net/teams/1369/60.png
# 65  https://cdn.sofifa.net/teams/1335/60.png
#
#                         nation_flag_url
# 5   https://cdn.sofifa.net/flags/se.png
# 8   https://cdn.sofifa.net/flags/br.png
# 47  https://cdn.sofifa.net/flags/uy.png
# 49  https://cdn.sofifa.net/flags/ar.png
# 65  https://cdn.sofifa.net/flags/fr.png

# %%
'''
df_jugadores_fifa_laliga['club_name'] = df_jugadores_fifa_laliga['club_name'].replace(
    'RCD Espanyol de Barcelona', 'RCD Espanyol'
)'
'''
# Out:
# "\ndf_jugadores_fifa_laliga['club_name'] = df_jugadores_fifa_laliga['club_name'].replace(\n    'RCD Espanyol de Barcelona', 'RCD Espanyol'\n)'\n"

# %%
valores_unicos_columna(df_jugadores_fifa_ligue1, 'club_name')
# Out:
# array(['Paris Saint-Germain', 'Olympique Lyonnais', 'AS Monaco',
#        'Olympique de Marseille', 'AS Saint-Étienne', 'LOSC Lille',
#        'Stade Rennais FC', 'FC Girondins de Bordeaux', 'OGC Nice',
#        'FC Nantes', 'Stade de Reims', 'Montpellier Hérault SC',
#        'Toulouse Football Club', 'Stade Malherbe Caen',
#        'En Avant de Guingamp', 'FC Lorient', 'ESTAC Troyes', 'SC Bastia',
#        'GFC Ajaccio', 'Angers SCO'], dtype=object)

# %%
# 1. Corrección manual de nombres específicos
df_jugadores_fifa_ligue1['club_name'] = df_jugadores_fifa_ligue1['club_name'].replace({
    'Stade Malherbe Caen': 'Caen',
    'Stade Rennais FC': 'Rennes',
    'Olympique Lyon': 'Lyon'
})

# %%
# Obtener valores únicos
equipos_fifa = df_jugadores_fifa_ligue1['club_name'].dropna().unique()
equipos_sb = df_jugadores['ultimo_equipo'].dropna().unique()

# Crear diccionario de traducción usando fuzzy matching
equipo_map = {}
for equipo_fifa in equipos_fifa:
    resultado = process.extractOne(equipo_fifa, equipos_sb, scorer=fuzz.token_sort_ratio)
    if resultado:
        mejor_match, score, _ = resultado
        if score >= 5:  # Solo si es un buen match
            equipo_map[equipo_fifa] = mejor_match
        else:
            equipo_map[equipo_fifa] = None  # Marca para revisar manualmente
    else:
        equipo_map[equipo_fifa] = None

# Aplicar la traducción a todo el dataset FIFA
df_fifa['club_name_original'] = df_fifa['club_name']  # Guardar original por seguridad
df_fifa['club_name'] = df_fifa['club_name'].map(equipo_map)

# %%
# 2. Filtrar jugadores de LaLiga en FIFA
df_jugadores_fifa_ligue1 = df_fifa[df_fifa['league_name'] == "French Ligue 1"].copy()

#df_jugadores_fifa_ligue1['club_name'] = df_jugadores_fifa_ligue1['club_name'].fillna('Espanyol')

df_jugadores_fifa_ligue1.head(5)
# Out:
#     sofifa_id                                         player_url  \
# 5       41236  https://sofifa.com/player/41236/zlatan-ibrahim...
# 8      164240  https://sofifa.com/player/164240/thiago-emilia...
# 47     179813  https://sofifa.com/player/179813/edinson-cavan...
# 49     183898  https://sofifa.com/player/183898/angel-di-mari...
# 65     170890  https://sofifa.com/player/170890/blaise-matuid...
#
#         short_name                        long_name player_positions  overall  \
# 5   Z. Ibrahimović               Zlatan Ibrahimović               ST       89
# 8     Thiago Silva         Thiago Emiliano da Silva               CB       88
# 47       E. Cavani     Edinson Roberto Cavani Gómez       ST, LW, RW       85
# 49     Á. Di María  Ángel Fabián Di María Hernández      CAM, CM, RM       85
# 65      B. Matuidi                   Blaise Matuidi          CDM, CM       84
#
#     potential   value_eur  wage_eur  age         dob  height_cm  weight_kg  \
# 5          89  40500000.0  220000.0   33  1981-10-03        195         95
# 8          88  38000000.0  200000.0   30  1984-09-22        183         79
# 47         85  33500000.0  200000.0   28  1987-02-14        184         71
# 49         85  34000000.0  200000.0   27  1988-02-14        180         75
# 65         85  25500000.0  180000.0   28  1987-04-09        175         70
#
#     club_team_id            club_name     league_name  league_level  \
# 5           73.0  Paris Saint-Germain  French Ligue 1           1.0
# 8           73.0  Paris Saint-Germain  French Ligue 1           1.0
# 47          73.0  Paris Saint-Germain  French Ligue 1           1.0
# 49          73.0  Paris Saint-Germain  French Ligue 1           1.0
# 65          73.0  Paris Saint-Germain  French Ligue 1           1.0
#
#    club_position  club_jersey_number club_loaned_from club_joined  \
# 5             ST                10.0              NaN  2012-07-01
# 8            RCB                 2.0              NaN  2012-07-01
# 47            RW                 9.0              NaN  2013-07-16
# 49            LW                11.0              NaN  2015-08-06
# 65           LCM                14.0              NaN  2011-07-01
#
#     club_contract_valid_until  nationality_id nationality_name  \
# 5                      2016.0              46           Sweden
# 8                      2018.0              54           Brazil
# 47                     2018.0              60          Uruguay
# 49                     2019.0              52        Argentina
# 65                     2018.0              18           France
#
#     nation_team_id nation_position  nation_jersey_number preferred_foot  \
# 5           1363.0              LS                  10.0          Right
# 8           1370.0             SUB                  14.0          Right
# 47          1377.0             SUB                  21.0          Right
# 49          1369.0              LW                   7.0           Left
# 65          1335.0             LCM                  14.0           Left
#
#     weak_foot  skill_moves  international_reputation    work_rate  \
# 5           4            4                         5   Medium/Low
# 8           3            3                         4    High/High
# 47          3            3                         4    High/High
# 49          2            4                         4  High/Medium
# 65          3            2                         3    High/High
#
#            body_type real_face  release_clause_eur  \
# 5      Normal (185+)       Yes                 NaN
# 8   Normal (170-185)       Yes                 NaN
# 47    Lean (170-185)       Yes                 NaN
# 49    Lean (170-185)       Yes                 NaN
# 65    Lean (170-185)       Yes                 NaN
#
#                                           player_tags  \
# 5   #Poacher, #Aerial Threat, #Distance Shooter, #...
# 8                              #Tackling, #Tactician
# 47                                            #Engine
# 49                      #Dribbler, #Crosser, #Acrobat
# 65                               #Engine, #Tactician
#
#                                         player_traits  pace  shooting  \
# 5   Power Free-Kick, Leadership, Flair, Long Shot ...  73.0      90.0
# 8          Leadership, Long Passer (AI), Power Header  74.0      57.0
# 47                    Beat Offside Trap, Power Header  76.0      83.0
# 49  Diver, Avoids Using Weaker Foot, Dives Into Ta...  88.0      79.0
# 65                           Injury Free, Team Player  75.0      67.0
#
#     passing  dribbling  defending  physic  attacking_crossing  \
# 5      81.0       85.0       31.0    86.0                  76
# 8      73.0       73.0       90.0    79.0                  60
# 47     71.0       81.0       42.0    80.0                  70
# 49     83.0       86.0       49.0    70.0                  90
# 65     77.0       75.0       83.0    81.0                  75
#
#     attacking_finishing  attacking_heading_accuracy  attacking_short_passing  \
# 5                    90                          76                       84
# 8                    38                          82                       79
# 47                   85                          86                       77
# 49                   75                          53                       81
# 65                   65                          73                       84
#
#     attacking_volleys  skill_dribbling  skill_curve  skill_fk_accuracy  \
# 5                  92               87           80                 80
# 8                  63               68           61                 73
# 47                 82               81           75                 77
# 49                 77               87           83                 72
# 65                 72               73           65                 52
#
#     skill_long_passing  skill_ball_control  movement_acceleration  \
# 5                   76                  90                     72
# 8                   81                  80                     72
# 47                  50                  83                     74
# 49                  81                  86                     88
# 65                  79                  77                     74
#
#     movement_sprint_speed  movement_agility  movement_reactions  \
# 5                      74                86                  85
# 8                      76                75                  84
# 47                     78                82                  85
# 49                     88                90                  80
# 65                     76                77                  83
#
#     movement_balance  power_shot_power  power_jumping  power_stamina  \
# 5                 41                93             72             75
# 8                 68                78             93             74
# 47                59                85             88             90
# 49                79                87             72             78
# 65                79                74             83             94
#
#     power_strength  power_long_shots  mentality_aggression  \
# 5               93                88                    84
# 8               81                71                    77
# 47              74                78                    82
# 49              64                79                    76
# 65              73                66                    84
#
#     mentality_interceptions  mentality_positioning  mentality_vision  \
# 5                        20                     86                83
# 8                        91                     59                74
# 47                       48                     85                77
# 49                       38                     84                83
# 65                       86                     70                74
#
#     mentality_penalties  mentality_composure  defending_marking_awareness  \
# 5                    91                  NaN                           15
# 8                    71                  NaN                           90
# 47                   82                  NaN                           24
# 49                   73                  NaN                           37
# 65                   56                  NaN                           82
#
#     defending_standing_tackle  defending_sliding_tackle  goalkeeping_diving  \
# 5                          41                        27                  13
# 8                          91                        89                   9
# 47                         45                        27                  12
# 49                         63                        61                  10
# 65                         84                        83                   8
#
#     goalkeeping_handling  goalkeeping_kicking  goalkeeping_positioning  \
# 5                     15                   10                        9
# 8                     12                    5                        9
# 47                     5                   13                       13
# 49                     7                   11                       12
# 65                    11                    5                       10
#
#     goalkeeping_reflexes  goalkeeping_speed    ls    st    rs    lw    lf  \
# 5                     12                NaN  86+3  86+3  86+3  84+3  86+3
# 8                     10                NaN  68+2  68+2  68+2  69+2  70+2
# 47                    10                NaN  83+2  83+2  83+2  80+2  82+2
# 49                    11                NaN  79+2  79+2  79+2  84+1  83+2
# 65                    14                NaN  73+1  73+1  73+1  75+1  74+1
#
#       cf    rf    rw   lam   cam   ram    lm   lcm    cm   rcm    rm   lwb  \
# 5   86+3  86+3  84+3  85+3  85+3  85+3  83+3  78+3  78+3  78+3  83+3  60+3
# 8   70+2  70+2  69+2  72+2  72+2  72+2  71+2  77+2  77+2  77+2  71+2  80+2
# 47  82+2  82+2  80+2  79+2  79+2  79+2  79+2  74+2  74+2  74+2  79+2  63+2
# 49  83+2  83+2  84+1  83+2  83+2  83+2  84+1  79+2  79+2  79+2  84+1  71+2
# 65  74+1  74+1  75+1  76+1  76+1  76+1  77+1  79+1  79+1  79+1  77+1  82+1
#
#      ldm   cdm   rdm   rwb    lb   lcb    cb   rcb    rb    gk  \
# 5   60+3  60+3  60+3  60+3  56+3  53+3  53+3  53+3  56+3  20+3
# 8   84+2  84+2  84+2  80+2  82+2  86+2  86+2  86+2  82+2  18+2
# 47  61+2  61+2  61+2  63+2  61+2  57+2  57+2  57+2  61+2  18+2
# 49  67+2  67+2  67+2  71+2  68+2  59+2  59+2  59+2  68+2  18+2
# 65  83+1  83+1  83+1  82+1  82+1  81+1  81+1  81+1  82+1  18+1
#
#                                       player_face_url  \
# 5   https://cdn.sofifa.net/players/041/236/16_120.png
# 8   https://cdn.sofifa.net/players/164/240/16_120.png
# 47  https://cdn.sofifa.net/players/179/813/16_120.png
# 49  https://cdn.sofifa.net/players/183/898/16_120.png
# 65  https://cdn.sofifa.net/players/170/890/16_120.png
#
#                              club_logo_url  \
# 5   https://cdn.sofifa.net/teams/73/60.png
# 8   https://cdn.sofifa.net/teams/73/60.png
# 47  https://cdn.sofifa.net/teams/73/60.png
# 49  https://cdn.sofifa.net/teams/73/60.png
# 65  https://cdn.sofifa.net/teams/73/60.png
#
#                           club_flag_url  \
# 5   https://cdn.sofifa.net/flags/fr.png
# 8   https://cdn.sofifa.net/flags/fr.png
# 47  https://cdn.sofifa.net/flags/fr.png
# 49  https://cdn.sofifa.net/flags/fr.png
# 65  https://cdn.sofifa.net/flags/fr.png
#
#                              nation_logo_url  \
# 5   https://cdn.sofifa.net/teams/1363/60.png
# 8   https://cdn.sofifa.net/teams/1370/60.png
# 47  https://cdn.sofifa.net/teams/1377/60.png
# 49  https://cdn.sofifa.net/teams/1369/60.png
# 65  https://cdn.sofifa.net/teams/1335/60.png
#
#                         nation_flag_url   club_name_original
# 5   https://cdn.sofifa.net/flags/se.png  Paris Saint-Germain
# 8   https://cdn.sofifa.net/flags/br.png  Paris Saint-Germain
# 47  https://cdn.sofifa.net/flags/uy.png  Paris Saint-Germain
# 49  https://cdn.sofifa.net/flags/ar.png  Paris Saint-Germain
# 65  https://cdn.sofifa.net/flags/fr.png  Paris Saint-Germain

# %%
valores_unicos_columna(df_jugadores_fifa_ligue1, 'club_name')

# los equipos que faltan son Caen y Rennes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 valores_unicos_columna(df_jugadores_fifa_ligue1, 'club_name')
#
# NameError: name 'valores_unicos_columna' is not defined

# %%
import pandas as pd
from rapidfuzz import process, fuzz

# 1. Cargar datasets ya cargados:
# df_jugadores
# df_jugadores_fifa_laliga

# 2. Fuzzy matching entre nombres de jugadores
def hacer_matching_aproximado(base_df, columna_base, df_referencia, columna_referencia, umbral=85):
    nombres_base = base_df[columna_base].unique()
    nombres_ref = df_referencia[columna_referencia].tolist()

    resultados = []

    for nombre in nombres_base:
        resultado = process.extractOne(nombre, nombres_ref, scorer=fuzz.token_sort_ratio)
        if resultado:
            mejor_match, score, _ = resultado
            revisar = score < umbral
        else:
            mejor_match, score, revisar = None, 0, True

        resultados.append({
            columna_base: nombre,
            f"{columna_referencia}_match": mejor_match,
            "score": score,
            "revisar": revisar
        })

    return pd.DataFrame(resultados)

# 3. Aplicar fuzzy matching jugador ↔ nombre FIFA
df_matching = hacer_matching_aproximado(
    base_df=df_jugadores,
    columna_base='player',
    df_referencia=df_jugadores_fifa_ligue1,
    columna_referencia='long_name',
    umbral=60
)

# 4. Merge para traer el match
jugadores_matcheados = df_jugadores.merge(df_matching, on='player')

# 5. Merge con FIFA para traer info de jugador
jugadores_completo = jugadores_matcheados.merge(
    df_jugadores_fifa_ligue1,
    left_on='long_name_match',
    right_on='long_name',
    how='left',
    suffixes=('', '_fifa')
)

# 6. Filtrar para que club_name (de FIFA) coincida con ultimo_equipo (StatsBomb)
jugadores_completo = jugadores_completo[jugadores_completo['ultimo_equipo'] == jugadores_completo['club_name']]

# 8. Mostrar jugadores que no se emparejaron bien
no_encontrados = jugadores_matcheados[~jugadores_matcheados['player'].isin(jugadores_completo['player'])]
print("\n❗ Jugadores que no se emparejaron con el mismo equipo:")
print(no_encontrados[['player', 'long_name_match', 'score', 'revisar']])
# Out:
# ✅ Archivo guardado como 'jugadores_con_datos_fifa_ligue1.csv'
#
# ❗ Jugadores que no se emparejaron con el mismo equipo:
#                     player          long_name_match       score  revisar
# 8            Ronny Rodelin     Sylvio Ronny Rodelin   78.787879     True
# 9             Julien Féret             Julien Féret  100.000000    False
# 11          Rémy Vercoutre           Rémy Vercoutre  100.000000    False
# 14   Christian Kouakou Yao  Lars Christian Jacobsen   63.636364     True
# 17         Samuel Grandsir               Paul Nardi   56.000000     True
# ..                     ...                      ...         ...      ...
# 565          Julien Romain          Romain Genevois   64.285714     True
# 567          Ilias Hassani           Thomas Mangani   51.851852     True
# 569         Antony Ranieri          Anthony Ribelin   75.862069     True
# 570           Jean Ambrose            Corentin Jean   56.000000     True
# 571            Diego Gómez           Manuel Delgado   48.000000     True
#
# [139 rows x 4 columns]

# %%
columnas_deseadas = [
    'player_id', 'player', 'ultimo_equipo', 'ultimo_team_id', 'posiciones', 'partidos_jugados',
    'overall', 'potential', 'value_eur', 'wage_eur', 'age', 'dob', 'height_cm', 'weight_kg',
    'club_jersey_number', 'club_loaned_from', 'club_contract_valid_until',
    'nationality_id', 'nationality_name', 'preferred_foot', 'release_clause_eur'
]

# Filtrar el DataFrame
jugadores_completo_filtrado = jugadores_completo[columnas_deseadas]

# Guardar si lo deseas
jugadores_completo_filtrado.to_csv("datos/jugadores_ligue1.csv", index=False)
print("✅ Archivo guardado como 'jugadores_filtrados_fifa_ligue1.csv'")
# Out:
# ✅ Archivo guardado como 'jugadores_filtrados_fifa_ligue1.csv'
