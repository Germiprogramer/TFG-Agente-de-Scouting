# %%
# !pip install langchain-experimental
# !pip install streamlit
# Out:
# Requirement already satisfied: langchain-experimental in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (0.3.4)
# Requirement already satisfied: langchain-community<0.4.0,>=0.3.0 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from langchain-experimental) (0.3.24)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.28 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from langchain-experimental) (0.3.60)
# Requirement already satisfied: langchain<1.0.0,>=0.3.25 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from langchain-community<0.4.0,>=0.3.0->langchain-experimental) (0.3.25)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from langchain-community<0.4.0,>=0.3.0->langchain-experimental) (2.0.41)
# Requirement already satisfied: requests<3,>=2 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from langchain-community<0.4.0,>=0.3.0->langchain-experimental) (2.31.0)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from langchain-community<0.4.0,>=0.3.0->langchain-experimental) (6.0.1)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from langchain-community<0.4.0,>=0.3.0->langchain-experimental) (3.11.18)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from langchain-community<0.4.0,>=0.3.0->langchain-experimental) (9.1.2)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from langchain-community<0.4.0,>=0.3.0->langchain-experimental) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from langchain-community<0.4.0,>=0.3.0->langchain-experimental) (2.9.1)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from langchain-community<0.4.0,>=0.3.0->langchain-experimental) (0.3.42)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from langchain-community<0.4.0,>=0.3.0->langchain-experimental) (0.4.0)
# Requirement already satisfied: numpy>=1.26.2 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from langchain-community<0.4.0,>=0.3.0->langchain-experimental) (1.26.4)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from langchain-core<0.4.0,>=0.3.28->langchain-experimental) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from langchain-core<0.4.0,>=0.3.28->langchain-experimental) (23.2)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from langchain-core<0.4.0,>=0.3.28->langchain-experimental) (4.12.2)
# Requirement already satisfied: pydantic>=2.7.4 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from langchain-core<0.4.0,>=0.3.28->langchain-experimental) (2.11.4)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (1.3.1)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (1.20.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (0.9.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.28->langchain-experimental) (3.0.0)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from langchain<1.0.0,>=0.3.25->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (0.3.8)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (0.27.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (3.10.10)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from pydantic>=2.7.4->langchain-core<0.4.0,>=0.3.28->langchain-experimental) (0.6.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from pydantic>=2.7.4->langchain-core<0.4.0,>=0.3.28->langchain-experimental) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from pydantic>=2.7.4->langchain-core<0.4.0,>=0.3.28->langchain-experimental) (0.4.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (1.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (2023.11.17)
# Requirement already satisfied: greenlet>=1 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (3.2.2)
# Requirement already satisfied: anyio in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (4.3.0)
# Requirement already satisfied: httpcore==1.* in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (1.0.5)
# Requirement already satisfied: sniffio in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (0.14.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (1.1.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\germán llorente\appdata\roaming\python\python39\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (1.2.0)
# WARNING: Ignoring invalid distribution -ransformers (c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ransformers (c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ransformers (c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages)
#
# [notice] A new release of pip is available: 24.2 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting streamlit
#   Downloading streamlit-1.45.1-py3-none-any.whl.metadata (8.9 kB)
# Collecting altair<6,>=4.0 (from streamlit)
#   Downloading altair-5.5.0-py3-none-any.whl.metadata (11 kB)
# Collecting blinker<2,>=1.5.0 (from streamlit)
#   Downloading blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from streamlit) (5.3.2)
# Requirement already satisfied: click<9,>=7.0 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from streamlit) (8.1.7)
# Requirement already satisfied: numpy<3,>=1.23 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from streamlit) (1.26.4)
# Requirement already satisfied: packaging<25,>=20 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from streamlit) (23.2)
# Requirement already satisfied: pandas<3,>=1.4.0 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from streamlit) (2.2.0)
# Requirement already satisfied: pillow<12,>=7.1.0 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from streamlit) (10.1.0)
# Collecting protobuf<7,>=3.20 (from streamlit)
#   Downloading protobuf-6.31.0-cp39-cp39-win_amd64.whl.metadata (593 bytes)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from streamlit) (15.0.0)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from streamlit) (2.31.0)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from streamlit) (9.1.2)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from streamlit) (4.12.2)
# Collecting watchdog<7,>=2.1.5 (from streamlit)
#   Downloading watchdog-6.0.0-py3-none-win_amd64.whl.metadata (44 kB)
# Collecting gitpython!=3.1.19,<4,>=3.0.7 (from streamlit)
#   Downloading GitPython-3.1.44-py3-none-any.whl.metadata (13 kB)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit)
#   Downloading pydeck-0.9.1-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\germán llorente\appdata\roaming\python\python39\site-packages (from streamlit) (6.4)
# Requirement already satisfied: jinja2 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from altair<6,>=4.0->streamlit) (3.1.3)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from altair<6,>=4.0->streamlit) (4.21.1)
# Collecting narwhals>=1.14.2 (from altair<6,>=4.0->streamlit)
#   Downloading narwhals-1.39.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: colorama in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Downloading gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.27->streamlit) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.27->streamlit) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.27->streamlit) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.27->streamlit) (2023.11.17)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Downloading smmap-5.0.2-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.33.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.18.0)
# Requirement already satisfied: six>=1.5 in c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.16.0)
# Downloading streamlit-1.45.1-py3-none-any.whl (9.9 MB)
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.9 MB 3.4 MB/s eta 0:00:03
#    ------ --------------------------------- 1.6/9.9 MB 4.2 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/9.9 MB 4.1 MB/s eta 0:00:02
#    ----------- ---------------------------- 2.9/9.9 MB 3.9 MB/s eta 0:00:02
#    --------------- ------------------------ 3.9/9.9 MB 4.0 MB/s eta 0:00:02
#    ------------------ --------------------- 4.5/9.9 MB 3.7 MB/s eta 0:00:02
#    -------------------- ------------------- 5.0/9.9 MB 3.8 MB/s eta 0:00:02
#    ----------------------- ---------------- 5.8/9.9 MB 3.7 MB/s eta 0:00:02
#    -------------------------- ------------- 6.6/9.9 MB 3.6 MB/s eta 0:00:01
#    ---------------------------- ----------- 7.1/9.9 MB 3.6 MB/s eta 0:00:01
#    ------------------------------- -------- 7.9/9.9 MB 3.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 8.7/9.9 MB 3.6 MB/s eta 0:00:01
#    -------------------------------------- - 9.4/9.9 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------- 9.9/9.9 MB 3.6 MB/s eta 0:00:00
# Downloading altair-5.5.0-py3-none-any.whl (731 kB)
#    ---------------------------------------- 0.0/731.2 kB ? eta -:--:--
#    ---------------------------------------- 731.2/731.2 kB 4.3 MB/s eta 0:00:00
# Downloading blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Downloading GitPython-3.1.44-py3-none-any.whl (207 kB)
# Downloading protobuf-6.31.0-cp39-cp39-win_amd64.whl (435 kB)
# Downloading pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
#    ---------------------------------------- 0.0/6.9 MB ? eta -:--:--
#    ---- ----------------------------------- 0.8/6.9 MB 3.7 MB/s eta 0:00:02
#    --------- ------------------------------ 1.6/6.9 MB 3.8 MB/s eta 0:00:02
#    ------------- -------------------------- 2.4/6.9 MB 3.8 MB/s eta 0:00:02
#    ------------------- -------------------- 3.4/6.9 MB 4.0 MB/s eta 0:00:01
#    ---------------------- ----------------- 3.9/6.9 MB 3.9 MB/s eta 0:00:01
#    --------------------------- ------------ 4.7/6.9 MB 3.8 MB/s eta 0:00:01
#    ------------------------------- -------- 5.5/6.9 MB 3.8 MB/s eta 0:00:01
#    ------------------------------------ --- 6.3/6.9 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------- 6.9/6.9 MB 3.8 MB/s eta 0:00:00
# Downloading watchdog-6.0.0-py3-none-win_amd64.whl (79 kB)
# Downloading gitdb-4.0.12-py3-none-any.whl (62 kB)
# Downloading narwhals-1.39.1-py3-none-any.whl (355 kB)
# Downloading smmap-5.0.2-py3-none-any.whl (24 kB)
# Installing collected packages: watchdog, smmap, protobuf, narwhals, blinker, pydeck, gitdb, gitpython, altair, streamlit
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.19.6
#     Uninstalling protobuf-3.19.6:
#       Successfully uninstalled protobuf-3.19.6
# Successfully installed altair-5.5.0 blinker-1.9.0 gitdb-4.0.12 gitpython-3.1.44 narwhals-1.39.1 protobuf-6.31.0 pydeck-0.9.1 smmap-5.0.2 streamlit-1.45.1 watchdog-6.0.0
# WARNING: Ignoring invalid distribution -ransformers (c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ransformers (c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ransformers (c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# googleapis-common-protos 1.61.0 requires protobuf!=3.20.0,!=3.20.1,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5, but you have protobuf 6.31.0 which is incompatible.
# mediapipe 0.10.8 requires protobuf<4,>=3.11, but you have protobuf 6.31.0 which is incompatible.
# tensorboard 2.11.2 requires protobuf<4,>=3.9.2, but you have protobuf 6.31.0 which is incompatible.
# tensorflow-intel 2.11.0 requires protobuf<3.20,>=3.9.2, but you have protobuf 6.31.0 which is incompatible.
# tensorflow-metadata 1.14.0 requires protobuf<4.21,>=3.20.3, but you have protobuf 6.31.0 which is incompatible.
#
# [notice] A new release of pip is available: 24.2 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install -r requirements.txt
# Out:
# Collecting aim==3.17.4 (from -r requirements.txt (line 1))
#   Using cached aim-3.17.4.tar.gz (1.6 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -ransformers (c:\users\germán llorente\appdata\local\programs\python\python39\lib\site-packages)
#   error: subprocess-exited-with-error
#
#   × pip subprocess to install build dependencies did not run successfully.
#   │ exit code: 1
#   ╰─> [6 lines of output]
#       Collecting setuptools
#         Using cached setuptools-80.7.1-py3-none-any.whl.metadata (6.6 kB)
#       Collecting cython==3.0.0a11
#         Using cached Cython-3.0.0a11-py2.py3-none-any.whl.metadata (2.7 kB)
#       ERROR: Could not find a version that satisfies the requirement aimrocks==0.4.0 (from versions: 0.2.0)
#       ERROR: No matching distribution found for aimrocks==0.4.0
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#
# [notice] A new release of pip is available: 24.2 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# error: subprocess-exited-with-error
#
# × pip subprocess to install build dependencies did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.

# %%
from langchain_experimental.agents import create_csv_agent
from langchain.llms import OpenAI
from dotenv import load_dotenv
import os
import streamlit as st

# %%
def main():
    load_dotenv()

    # Load the OpenAI API key from the environment variable
    if os.getenv("OPENAI_API_KEY") is None or os.getenv("OPENAI_API_KEY") == "":
        print("OPENAI_API_KEY is not set")
        exit(1)
    else:
        print("OPENAI_API_KEY is set") 

    st.set_page_config(page_title="Ask your CSV")
    st.header("Ask your CSV 📈")

    csv_file = st.file_uploader("Upload a CSV file", type="csv")
    if csv_file is not None:

        agent = create_csv_agent(
            OpenAI(temperature=0), csv_file, verbose=True)

        user_question = st.text_input("Ask a question about your CSV: ")

        if user_question is not None and user_question != "":
            with st.spinner(text="In progress..."):
                st.write(agent.run(user_question))


if __name__ == "__main__":
    main()
# Out:
# 2025-05-18 11:06:38.622 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-18 11:06:38.624 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-18 11:06:38.625 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-18 11:06:38.626 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-18 11:06:38.627 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-18 11:06:38.627 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-18 11:06:38.628 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-18 11:06:38.628 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# OPENAI_API_KEY is set
